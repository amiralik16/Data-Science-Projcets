# %%
import numpy as np
import pandas as pd
from pylab import plot,show
from numpy import *
from alpha_vantage.timeseries import TimeSeries
from alpha_vantage.techindicators import TechIndicators

# %%
ts = TimeSeries(key='ARTSA8ZXDXMI2GB4', output_format='pandas',indexing_type='integer')

# %%
temp = ts.get_daily('SPY',outputsize='full')

# %%
closes = temp[0]['4. close'][:]
plot(closes); show()

# %%
temp[0]
# Out:
#             date   1. open   2. high    3. low  4. close    5. volume
# 0     1998-01-02   97.3125   97.6562   96.5312   97.5625    2360900.0
# 1     1998-01-05   97.8437   98.4375   96.7812   97.7812    4191800.0
# 2     1998-01-06   97.2500   97.2812   96.1875   96.2187    3154900.0
# 3     1998-01-07   96.0937   96.7187   95.2187   96.4687    4424200.0
# 4     1998-01-08   96.3125   96.3125   95.3750   95.6250    3831000.0
# 5     1998-01-09   95.2500   95.5000   91.9062   92.3125   10258800.0
# 6     1998-01-12   91.1250   94.1875   90.9062   94.0000   12097900.0
# 7     1998-01-13   94.6250   95.3750   94.2187   95.3125    5224900.0
# 8     1998-01-14   95.6875   95.9687   94.7187   95.7500    3770400.0
# 9     1998-01-15   95.5000   95.7500   94.8125   94.9531    2875400.0
# 10    1998-01-16   96.2500   96.6875   95.6562   96.3125    4374800.0
# 11    1998-01-20   96.6875   98.0156   96.5000   97.8750    5091700.0
# ...

# %%
lag1 = 2
lags = range(lag1, 20)
tau = [sqrt(std(subtract(closes[lag:], closes[:-lag]))) for lag in lags]
plot(log(lags), log(tau)); show()
m = polyfit(log(lags), log(tau), 1)
hurst = m[0]*2
print(f"hurst = {hurst}")
# Out:
# hurst = 0.43175278475216394
