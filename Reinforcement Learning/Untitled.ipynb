# %%
import numpy as np
import gym

from keras.models import Sequential
from keras.layers import Dense, Activation, Flatten
from keras.optimizers import Adam

from rl.agents.cem import CEMAgent
from rl.memory import EpisodeParameterMemory

ENV_NAME = 'CartPole-v0'


# Get the environment and extract the number of actions.
env = gym.make(ENV_NAME)
np.random.seed(123)
env.seed(123)

nb_actions = env.action_space.n
obs_dim = env.observation_space.shape[0]

# Option 1 : Simple model
# model = Sequential()
# model.add(Flatten(input_shape=(1,) + env.observation_space.shape))
# model.add(Dense(nb_actions))
# model.add(Activation('softmax'))

# Option 2: deep network
model = Sequential()
model.add(Flatten(input_shape=(1,) + env.observation_space.shape))
model.add(Dense(16))
model.add(Activation('relu'))
model.add(Dense(16))
model.add(Activation('relu'))
model.add(Dense(16))
model.add(Activation('relu'))
model.add(Dense(nb_actions))
model.add(Activation('softmax'))


print(model.summary())


# Finally, we configure and compile our agent. You can use every built-in Keras optimizer and
# even the metrics!
memory = EpisodeParameterMemory(limit=1000, window_length=1)

cem = CEMAgent(model=model, nb_actions=nb_actions, memory=memory,
               batch_size=50, nb_steps_warmup=2000, train_interval=50, elite_frac=0.05)
cem.compile()

# Okay, now it's time to learn something! We visualize the training here for show, but this
# slows down training quite a lot. You can always safely abort the training prematurely using
# Ctrl + C.
cem.fit(env, nb_steps=100000, visualize=False, verbose=2)

# After training is done, we save the best weights.
cem.save_weights('cem_{}_params.h5f'.format(ENV_NAME), overwrite=True)

# Finally, evaluate our algorithm for 5 episodes.
cem.test(env, nb_episodes=20, visualize=True)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_2 (Flatten)          (None, 4)                 0
# _________________________________________________________________
# dense_2 (Dense)              (None, 16)                80
# _________________________________________________________________
# activation_2 (Activation)    (None, 16)                0
# _________________________________________________________________
# dense_3 (Dense)              (None, 16)                272
# _________________________________________________________________
# activation_3 (Activation)    (None, 16)                0
# _________________________________________________________________
# dense_4 (Dense)              (None, 16)                272
# _________________________________________________________________
# activation_4 (Activation)    (None, 16)                0
# _________________________________________________________________
# dense_5 (Dense)              (None, 2)                 34
# _________________________________________________________________
# activation_5 (Activation)    (None, 2)                 0
# =================================================================
# Total params: 658
# Trainable params: 658
# Non-trainable params: 0
# _________________________________________________________________
# None
# Training for 100000 steps ...
#     22/100000: episode: 1, duration: 0.103s, episode steps: 22, steps per second: 214, episode reward: 22.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.455 [0.000, 1.000], mean observation: -0.105 [-0.935, 0.391], mean_best_reward: --
#     36/100000: episode: 2, duration: 0.021s, episode steps: 14, steps per second: 665, episode reward: 14.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.286 [0.000, 1.000], mean observation: 0.138 [-1.137, 2.156], mean_best_reward: --
#     59/100000: episode: 3, duration: 0.035s, episode steps: 23, steps per second: 664, episode reward: 23.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.391 [0.000, 1.000], mean observation: 0.097 [-0.944, 1.927], mean_best_reward: --
#     71/100000: episode: 4, duration: 0.019s, episode steps: 12, steps per second: 629, episode reward: 12.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.750 [0.000, 1.000], mean observation: -0.117 [-2.212, 1.349], mean_best_reward: --
#     81/100000: episode: 5, duration: 0.016s, episode steps: 10, steps per second: 610, episode reward: 10.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.700 [0.000, 1.000], mean observation: -0.099 [-1.911, 1.213], mean_best_reward: --
#     94/100000: episode: 6, duration: 0.020s, episode steps: 13, steps per second: 635, episode reward: 13.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.692 [0.000, 1.000], mean observation: -0.091 [-1.766, 0.996], mean_best_reward: --
#    106/100000: episode: 7, duration: 0.018s, episode steps: 12, steps per second: 650, episode reward: 12.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.167 [0.000, 1.000], mean observation: 0.119 [-1.524, 2.522], mean_best_reward: --
#    117/100000: episode: 8, duration: 0.018s, episode steps: 11, steps per second: 608, episode reward: 11.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.364 [0.000, 1.000], mean observation: 0.110 [-0.984, 1.562], mean_best_reward: --
#    130/100000: episode: 9, duration: 0.020s, episode steps: 13, steps per second: 639, episode reward: 13.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.231 [0.000, 1.000], mean observation: 0.128 [-1.331, 2.344], mean_best_reward: --
#    186/100000: episode: 10, duration: 0.076s, episode steps: 56, steps per second: 734, episode reward: 56.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.429 [0.000, 1.000], mean observation: -0.108 [-1.910, 1.696], mean_best_reward: --
#    199/100000: episode: 11, duration: 0.020s, episode steps: 13, steps per second: 654, episode reward: 13.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.154 [0.000, 1.000], mean observation: 0.099 [-1.788, 2.784], mean_best_reward: --
#    227/100000: episode: 12, duration: 0.037s, episode steps: 28, steps per second: 750, episode reward: 28.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.571 [0.000, 1.000], mean observation: -0.067 [-1.720, 0.844], mean_best_reward: --
#    240/100000: episode: 13, duration: 0.019s, episode steps: 13, steps per second: 667, episode reward: 13.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.692 [0.000, 1.000], mean observation: -0.091 [-1.829, 1.030], mean_best_reward: --
#    263/100000: episode: 14, duration: 0.032s, episode steps: 23, steps per second: 728, episode reward: 23.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.522 [0.000, 1.000], mean observation: -0.083 [-1.057, 0.427], mean_best_reward: --
#    274/100000: episode: 15, duration: 0.021s, episode steps: 11, steps per second: 526, episode reward: 11.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.273 [0.000, 1.000], mean observation: 0.107 [-1.185, 1.974], mean_best_reward: --
#    283/100000: episode: 16, duration: 0.015s, episode steps: 9, steps per second: 585, episode reward: 9.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.111 [0.000, 1.000], mean observation: 0.132 [-1.365, 2.274], mean_best_reward: --
#    298/100000: episode: 17, duration: 0.022s, episode steps: 15, steps per second: 667, episode reward: 15.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.267 [0.000, 1.000], mean observation: 0.077 [-1.545, 2.383], mean_best_reward: --
#    311/100000: episode: 18, duration: 0.019s, episode steps: 13, steps per second: 672, episode reward: 13.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.692 [0.000, 1.000], mean observation: -0.105 [-1.989, 1.169], mean_best_reward: --
#    325/100000: episode: 19, duration: 0.025s, episode steps: 14, steps per second: 551, episode reward: 14.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.714 [0.000, 1.000], mean observation: -0.076 [-2.020, 1.205], mean_best_reward: --
#    351/100000: episode: 20, duration: 0.035s, episode steps: 26, steps per second: 742, episode reward: 26.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.538 [0.000, 1.000], mean observation: -0.058 [-1.307, 0.609], mean_best_reward: --
#    368/100000: episode: 21, duration: 0.026s, episode steps: 17, steps per second: 661, episode reward: 17.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.471 [0.000, 1.000], mean observation: 0.128 [-0.567, 0.974], mean_best_reward: --
#    385/100000: episode: 22, duration: 0.025s, episode steps: 17, steps per second: 676, episode reward: 17.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.235 [0.000, 1.000], mean observation: 0.068 [-1.769, 2.724], mean_best_reward: --
#    402/100000: episode: 23, duration: 0.025s, episode steps: 17, steps per second: 671, episode reward: 17.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.647 [0.000, 1.000], mean observation: -0.067 [-1.730, 1.024], mean_best_reward: --
#    416/100000: episode: 24, duration: 0.020s, episode steps: 14, steps per second: 704, episode reward: 14.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.357 [0.000, 1.000], mean observation: 0.117 [-0.973, 1.745], mean_best_reward: --
#    449/100000: episode: 25, duration: 0.045s, episode steps: 33, steps per second: 734, episode reward: 33.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.455 [0.000, 1.000], mean observation: 0.042 [-0.625, 1.452], mean_best_reward: --
#    470/100000: episode: 26, duration: 0.034s, episode steps: 21, steps per second: 619, episode reward: 21.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.429 [0.000, 1.000], mean observation: 0.107 [-0.790, 1.798], mean_best_reward: --
#    481/100000: episode: 27, duration: 0.018s, episode steps: 11, steps per second: 600, episode reward: 11.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.818 [0.000, 1.000], mean observation: -0.134 [-2.330, 1.365], mean_best_reward: --
#    493/100000: episode: 28, duration: 0.018s, episode steps: 12, steps per second: 676, episode reward: 12.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.667 [0.000, 1.000], mean observation: -0.120 [-1.812, 1.126], mean_best_reward: --
#    515/100000: episode: 29, duration: 0.031s, episode steps: 22, steps per second: 713, episode reward: 22.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.682 [0.000, 1.000], mean observation: -0.019 [-2.602, 1.799], mean_best_reward: --
#    533/100000: episode: 30, duration: 0.029s, episode steps: 18, steps per second: 618, episode reward: 18.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.333 [0.000, 1.000], mean observation: 0.073 [-1.133, 1.946], mean_best_reward: --
#    543/100000: episode: 31, duration: 0.017s, episode steps: 10, steps per second: 573, episode reward: 10.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.000 [0.000, 0.000], mean observation: 0.127 [-1.985, 3.032], mean_best_reward: --
#    554/100000: episode: 32, duration: 0.019s, episode steps: 11, steps per second: 584, episode reward: 11.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.182 [0.000, 1.000], mean observation: 0.109 [-1.421, 2.355], mean_best_reward: --
#    564/100000: episode: 33, duration: 0.018s, episode steps: 10, steps per second: 553, episode reward: 10.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.900 [0.000, 1.000], mean observation: -0.130 [-2.551, 1.590], mean_best_reward: --
#    575/100000: episode: 34, duration: 0.023s, episode steps: 11, steps per second: 480, episode reward: 11.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.182 [0.000, 1.000], mean observation: 0.139 [-1.325, 2.327], mean_best_reward: --
#    595/100000: episode: 35, duration: 0.029s, episode steps: 20, steps per second: 678, episode reward: 20.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.600 [0.000, 1.000], mean observation: -0.078 [-1.525, 0.774], mean_best_reward: --
#    615/100000: episode: 36, duration: 0.029s, episode steps: 20, steps per second: 683, episode reward: 20.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.600 [0.000, 1.000], mean observation: -0.087 [-1.785, 0.967], mean_best_reward: --
#    629/100000: episode: 37, duration: 0.023s, episode steps: 14, steps per second: 607, episode reward: 14.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.143 [0.000, 1.000], mean observation: 0.101 [-1.937, 3.023], mean_best_reward: --
#    648/100000: episode: 38, duration: 0.028s, episode steps: 19, steps per second: 676, episode reward: 19.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.263 [0.000, 1.000], mean observation: 0.070 [-1.741, 2.811], mean_best_reward: --
#    661/100000: episode: 39, duration: 0.019s, episode steps: 13, steps per second: 693, episode reward: 13.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.154 [0.000, 1.000], mean observation: 0.101 [-1.764, 2.781], mean_best_reward: --
#    684/100000: episode: 40, duration: 0.032s, episode steps: 23, steps per second: 714, episode reward: 23.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.522 [0.000, 1.000], mean observation: -0.087 [-1.068, 0.581], mean_best_reward: --
#    705/100000: episode: 41, duration: 0.035s, episode steps: 21, steps per second: 603, episode reward: 21.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.524 [0.000, 1.000], mean observation: 0.108 [-0.406, 1.051], mean_best_reward: --
#    717/100000: episode: 42, duration: 0.018s, episode steps: 12, steps per second: 651, episode reward: 12.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.167 [0.000, 1.000], mean observation: 0.094 [-1.616, 2.549], mean_best_reward: --
#    730/100000: episode: 43, duration: 0.019s, episode steps: 13, steps per second: 681, episode reward: 13.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.846 [0.000, 1.000], mean observation: -0.072 [-2.654, 1.795], mean_best_reward: --
#    740/100000: episode: 44, duration: 0.016s, episode steps: 10, steps per second: 633, episode reward: 10.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.900 [0.000, 1.000], mean observation: -0.128 [-2.587, 1.608], mean_best_reward: --
#    756/100000: episode: 45, duration: 0.024s, episode steps: 16, steps per second: 668, episode reward: 16.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.812 [0.000, 1.000], mean observation: -0.067 [-3.029, 1.994], mean_best_reward: --
#    770/100000: episode: 46, duration: 0.021s, episode steps: 14, steps per second: 659, episode reward: 14.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.857 [0.000, 1.000], mean observation: -0.066 [-2.985, 1.988], mean_best_reward: --
#    790/100000: episode: 47, duration: 0.027s, episode steps: 20, steps per second: 743, episode reward: 20.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.500 [0.000, 1.000], mean observation: -0.068 [-1.197, 0.821], mean_best_reward: --
#    921/100000: episode: 48, duration: 0.166s, episode steps: 131, steps per second: 787, episode reward: 131.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.489 [0.000, 1.000], mean observation: -0.056 [-1.179, 1.223], mean_best_reward: --
#    934/100000: episode: 49, duration: 0.020s, episode steps: 13, steps per second: 650, episode reward: 13.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.231 [0.000, 1.000], mean observation: 0.097 [-1.380, 2.258], mean_best_reward: --
#    979/100000: episode: 50, duration: 0.053s, episode steps: 45, steps per second: 852, episode reward: 45.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.422 [0.000, 1.000], mean observation: -0.025 [-1.383, 1.979], mean_best_reward: --
#    988/100000: episode: 51, duration: 0.014s, episode steps: 9, steps per second: 639, episode reward: 9.000, mean reward: 1.000 [1.000, 1.000], mean action: 1.000 [1.000, 1.000], mean observation: -0.143 [-2.795, 1.795], mean_best_reward: --
#   1000/100000: episode: 52, duration: 0.016s, episode steps: 12, steps per second: 744, episode reward: 12.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.167 [0.000, 1.000], mean observation: 0.103 [-1.791, 2.678], mean_best_reward: --
#   1014/100000: episode: 53, duration: 0.019s, episode steps: 14, steps per second: 743, episode reward: 14.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.714 [0.000, 1.000], mean observation: -0.109 [-2.121, 1.144], mean_best_reward: --
#   1043/100000: episode: 54, duration: 0.037s, episode steps: 29, steps per second: 779, episode reward: 29.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.379 [0.000, 1.000], mean observation: 0.004 [-1.747, 2.347], mean_best_reward: --
#   1060/100000: episode: 55, duration: 0.021s, episode steps: 17, steps per second: 797, episode reward: 17.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.294 [0.000, 1.000], mean observation: 0.090 [-1.358, 2.368], mean_best_reward: --
#   1071/100000: episode: 56, duration: 0.015s, episode steps: 11, steps per second: 716, episode reward: 11.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.182 [0.000, 1.000], mean observation: 0.107 [-1.594, 2.449], mean_best_reward: --
#   1107/100000: episode: 57, duration: 0.051s, episode steps: 36, steps per second: 706, episode reward: 36.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.528 [0.000, 1.000], mean observation: -0.049 [-1.349, 0.592], mean_best_reward: --
#   1119/100000: episode: 58, duration: 0.019s, episode steps: 12, steps per second: 636, episode reward: 12.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.167 [0.000, 1.000], mean observation: 0.109 [-1.539, 2.542], mean_best_reward: --
#   1143/100000: episode: 59, duration: 0.031s, episode steps: 24, steps per second: 775, episode reward: 24.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.500 [0.000, 1.000], mean observation: 0.085 [-0.497, 0.845], mean_best_reward: --
#   1174/100000: episode: 60, duration: 0.041s, episode steps: 31, steps per second: 751, episode reward: 31.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.548 [0.000, 1.000], mean observation: -0.113 [-1.876, 0.587], mean_best_reward: --
#   1185/100000: episode: 61, duration: 0.018s, episode steps: 11, steps per second: 625, episode reward: 11.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.182 [0.000, 1.000], mean observation: 0.112 [-1.387, 2.278], mean_best_reward: --
#   1205/100000: episode: 62, duration: 0.027s, episode steps: 20, steps per second: 747, episode reward: 20.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.600 [0.000, 1.000], mean observation: -0.058 [-2.030, 1.370], mean_best_reward: --
#   1217/100000: episode: 63, duration: 0.017s, episode steps: 12, steps per second: 708, episode reward: 12.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.667 [0.000, 1.000], mean observation: -0.111 [-1.802, 1.028], mean_best_reward: --
#   1236/100000: episode: 64, duration: 0.028s, episode steps: 19, steps per second: 671, episode reward: 19.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.263 [0.000, 1.000], mean observation: 0.081 [-1.720, 2.826], mean_best_reward: --
#   1246/100000: episode: 65, duration: 0.018s, episode steps: 10, steps per second: 545, episode reward: 10.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.900 [0.000, 1.000], mean observation: -0.131 [-2.538, 1.553], mean_best_reward: --
#   1271/100000: episode: 66, duration: 0.032s, episode steps: 25, steps per second: 777, episode reward: 25.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.480 [0.000, 1.000], mean observation: -0.101 [-0.897, 0.414], mean_best_reward: --
#   1284/100000: episode: 67, duration: 0.019s, episode steps: 13, steps per second: 678, episode reward: 13.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.538 [0.000, 1.000], mean observation: -0.116 [-1.267, 0.780], mean_best_reward: --
#   1294/100000: episode: 68, duration: 0.015s, episode steps: 10, steps per second: 684, episode reward: 10.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.100 [0.000, 1.000], mean observation: 0.131 [-1.546, 2.555], mean_best_reward: --
#   1306/100000: episode: 69, duration: 0.016s, episode steps: 12, steps per second: 748, episode reward: 12.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.750 [0.000, 1.000], mean observation: -0.122 [-2.040, 1.194], mean_best_reward: --
#   1318/100000: episode: 70, duration: 0.016s, episode steps: 12, steps per second: 728, episode reward: 12.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.167 [0.000, 1.000], mean observation: 0.127 [-1.551, 2.505], mean_best_reward: --
#   1326/100000: episode: 71, duration: 0.013s, episode steps: 8, steps per second: 598, episode reward: 8.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.125 [0.000, 1.000], mean observation: 0.137 [-1.415, 2.186], mean_best_reward: --
#   1346/100000: episode: 72, duration: 0.029s, episode steps: 20, steps per second: 690, episode reward: 20.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.550 [0.000, 1.000], mean observation: -0.054 [-1.264, 0.816], mean_best_reward: --
#   1397/100000: episode: 73, duration: 0.063s, episode steps: 51, steps per second: 805, episode reward: 51.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.627 [0.000, 1.000], mean observation: 0.044 [-3.052, 2.456], mean_best_reward: --
#   1408/100000: episode: 74, duration: 0.018s, episode steps: 11, steps per second: 625, episode reward: 11.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.273 [0.000, 1.000], mean observation: 0.141 [-0.953, 1.801], mean_best_reward: --
#   1417/100000: episode: 75, duration: 0.015s, episode steps: 9, steps per second: 600, episode reward: 9.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.000 [0.000, 0.000], mean observation: 0.149 [-1.740, 2.796], mean_best_reward: --
#   1438/100000: episode: 76, duration: 0.031s, episode steps: 21, steps per second: 682, episode reward: 21.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.333 [0.000, 1.000], mean observation: 0.091 [-1.522, 2.486], mean_best_reward: --
#   1447/100000: episode: 77, duration: 0.017s, episode steps: 9, steps per second: 534, episode reward: 9.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.889 [0.000, 1.000], mean observation: -0.151 [-2.333, 1.399], mean_best_reward: --
#   1465/100000: episode: 78, duration: 0.025s, episode steps: 18, steps per second: 725, episode reward: 18.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.778 [0.000, 1.000], mean observation: -0.053 [-2.998, 1.993], mean_best_reward: --
#   1478/100000: episode: 79, duration: 0.019s, episode steps: 13, steps per second: 676, episode reward: 13.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.231 [0.000, 1.000], mean observation: 0.108 [-1.339, 2.284], mean_best_reward: --
#   1489/100000: episode: 80, duration: 0.017s, episode steps: 11, steps per second: 659, episode reward: 11.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.818 [0.000, 1.000], mean observation: -0.121 [-2.270, 1.416], mean_best_reward: --
#   1503/100000: episode: 81, duration: 0.021s, episode steps: 14, steps per second: 654, episode reward: 14.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.286 [0.000, 1.000], mean observation: 0.114 [-1.171, 2.104], mean_best_reward: --
#   1515/100000: episode: 82, duration: 0.017s, episode steps: 12, steps per second: 698, episode reward: 12.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.250 [0.000, 1.000], mean observation: 0.110 [-1.136, 1.944], mean_best_reward: --
#   1567/100000: episode: 83, duration: 0.065s, episode steps: 52, steps per second: 801, episode reward: 52.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.481 [0.000, 1.000], mean observation: 0.023 [-0.877, 1.213], mean_best_reward: --
#   1579/100000: episode: 84, duration: 0.018s, episode steps: 12, steps per second: 685, episode reward: 12.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.167 [0.000, 1.000], mean observation: 0.116 [-1.524, 2.545], mean_best_reward: --
#   1590/100000: episode: 85, duration: 0.016s, episode steps: 11, steps per second: 678, episode reward: 11.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.818 [0.000, 1.000], mean observation: -0.118 [-2.257, 1.363], mean_best_reward: --
#   1604/100000: episode: 86, duration: 0.019s, episode steps: 14, steps per second: 729, episode reward: 14.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.357 [0.000, 1.000], mean observation: 0.104 [-0.977, 1.732], mean_best_reward: --
#   1617/100000: episode: 87, duration: 0.018s, episode steps: 13, steps per second: 709, episode reward: 13.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.154 [0.000, 1.000], mean observation: 0.123 [-1.714, 2.788], mean_best_reward: --
#   1638/100000: episode: 88, duration: 0.033s, episode steps: 21, steps per second: 646, episode reward: 21.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.571 [0.000, 1.000], mean observation: -0.088 [-1.778, 0.954], mean_best_reward: --
#   1655/100000: episode: 89, duration: 0.022s, episode steps: 17, steps per second: 782, episode reward: 17.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.647 [0.000, 1.000], mean observation: -0.076 [-1.733, 0.962], mean_best_reward: --
#   1667/100000: episode: 90, duration: 0.020s, episode steps: 12, steps per second: 602, episode reward: 12.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.833 [0.000, 1.000], mean observation: -0.133 [-2.673, 1.612], mean_best_reward: --
#   1677/100000: episode: 91, duration: 0.015s, episode steps: 10, steps per second: 679, episode reward: 10.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.900 [0.000, 1.000], mean observation: -0.124 [-2.623, 1.618], mean_best_reward: --
#   1691/100000: episode: 92, duration: 0.019s, episode steps: 14, steps per second: 735, episode reward: 14.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.571 [0.000, 1.000], mean observation: -0.103 [-1.258, 0.760], mean_best_reward: --
#   1700/100000: episode: 93, duration: 0.014s, episode steps: 9, steps per second: 648, episode reward: 9.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.778 [0.000, 1.000], mean observation: -0.138 [-1.941, 1.175], mean_best_reward: --
#   1714/100000: episode: 94, duration: 0.020s, episode steps: 14, steps per second: 688, episode reward: 14.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.286 [0.000, 1.000], mean observation: 0.090 [-1.394, 2.207], mean_best_reward: --
#   1727/100000: episode: 95, duration: 0.018s, episode steps: 13, steps per second: 724, episode reward: 13.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.846 [0.000, 1.000], mean observation: -0.092 [-2.735, 1.796], mean_best_reward: --
#   1739/100000: episode: 96, duration: 0.017s, episode steps: 12, steps per second: 727, episode reward: 12.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.833 [0.000, 1.000], mean observation: -0.112 [-2.606, 1.616], mean_best_reward: --
#   1748/100000: episode: 97, duration: 0.013s, episode steps: 9, steps per second: 681, episode reward: 9.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.778 [0.000, 1.000], mean observation: -0.139 [-1.836, 1.160], mean_best_reward: --
#   1762/100000: episode: 98, duration: 0.019s, episode steps: 14, steps per second: 741, episode reward: 14.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.857 [0.000, 1.000], mean observation: -0.100 [-3.033, 1.983], mean_best_reward: --
#   1781/100000: episode: 99, duration: 0.023s, episode steps: 19, steps per second: 829, episode reward: 19.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.474 [0.000, 1.000], mean observation: 0.096 [-0.596, 1.129], mean_best_reward: --
#   1796/100000: episode: 100, duration: 0.019s, episode steps: 15, steps per second: 792, episode reward: 15.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.533 [0.000, 1.000], mean observation: -0.117 [-1.657, 0.941], mean_best_reward: --
#   1810/100000: episode: 101, duration: 0.024s, episode steps: 14, steps per second: 588, episode reward: 14.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.643 [0.000, 1.000], mean observation: -0.119 [-1.611, 0.805], mean_best_reward: --
#   1827/100000: episode: 102, duration: 0.023s, episode steps: 17, steps per second: 725, episode reward: 17.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.294 [0.000, 1.000], mean observation: 0.052 [-1.569, 2.287], mean_best_reward: --
#   1845/100000: episode: 103, duration: 0.023s, episode steps: 18, steps per second: 778, episode reward: 18.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.556 [0.000, 1.000], mean observation: -0.088 [-1.376, 0.615], mean_best_reward: --
#   1857/100000: episode: 104, duration: 0.018s, episode steps: 12, steps per second: 668, episode reward: 12.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.250 [0.000, 1.000], mean observation: 0.107 [-1.180, 2.056], mean_best_reward: --
#   1870/100000: episode: 105, duration: 0.018s, episode steps: 13, steps per second: 710, episode reward: 13.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.692 [0.000, 1.000], mean observation: -0.119 [-1.864, 0.974], mean_best_reward: --
#   1879/100000: episode: 106, duration: 0.015s, episode steps: 9, steps per second: 598, episode reward: 9.000, mean reward: 1.000 [1.000, 1.000], mean action: 1.000 [1.000, 1.000], mean observation: -0.161 [-2.852, 1.755], mean_best_reward: --
#   1908/100000: episode: 107, duration: 0.037s, episode steps: 29, steps per second: 785, episode reward: 29.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.379 [0.000, 1.000], mean observation: 0.046 [-1.355, 2.207], mean_best_reward: --
#   1920/100000: episode: 108, duration: 0.017s, episode steps: 12, steps per second: 688, episode reward: 12.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.333 [0.000, 1.000], mean observation: 0.130 [-1.129, 1.818], mean_best_reward: --
#   1931/100000: episode: 109, duration: 0.017s, episode steps: 11, steps per second: 642, episode reward: 11.000, mean reward: 1.000 [1.000, 1.000], mean action: 1.000 [1.000, 1.000], mean observation: -0.130 [-3.285, 2.182], mean_best_reward: --
#   1946/100000: episode: 110, duration: 0.022s, episode steps: 15, steps per second: 690, episode reward: 15.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.667 [0.000, 1.000], mean observation: -0.098 [-1.916, 1.178], mean_best_reward: --
#   1958/100000: episode: 111, duration: 0.019s, episode steps: 12, steps per second: 648, episode reward: 12.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.250 [0.000, 1.000], mean observation: 0.095 [-1.190, 1.983], mean_best_reward: --
#   1967/100000: episode: 112, duration: 0.013s, episode steps: 9, steps per second: 670, episode reward: 9.000, mean reward: 1.000 [1.000, 1.000], mean action: 1.000 [1.000, 1.000], mean observation: -0.152 [-2.866, 1.782], mean_best_reward: --
#   1980/100000: episode: 113, duration: 0.019s, episode steps: 13, steps per second: 674, episode reward: 13.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.769 [0.000, 1.000], mean observation: -0.091 [-2.278, 1.400], mean_best_reward: --
#   1988/100000: episode: 114, duration: 0.012s, episode steps: 8, steps per second: 677, episode reward: 8.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.000 [0.000, 0.000], mean observation: 0.127 [-1.601, 2.540], mean_best_reward: --
#   2008/100000: episode: 115, duration: 0.026s, episode steps: 20, steps per second: 756, episode reward: 20.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.600 [0.000, 1.000], mean observation: -0.086 [-1.734, 0.951], mean_best_reward: --
#   2034/100000: episode: 116, duration: 0.032s, episode steps: 26, steps per second: 804, episode reward: 26.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.577 [0.000, 1.000], mean observation: -0.093 [-1.918, 0.946], mean_best_reward: --
#   2049/100000: episode: 117, duration: 0.021s, episode steps: 15, steps per second: 718, episode reward: 15.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.267 [0.000, 1.000], mean observation: 0.086 [-1.364, 2.210], mean_best_reward: --
#   2063/100000: episode: 118, duration: 0.019s, episode steps: 14, steps per second: 729, episode reward: 14.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.571 [0.000, 1.000], mean observation: -0.109 [-1.253, 0.576], mean_best_reward: --
#   2086/100000: episode: 119, duration: 0.033s, episode steps: 23, steps per second: 701, episode reward: 23.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.435 [0.000, 1.000], mean observation: 0.030 [-0.963, 1.386], mean_best_reward: --
#   2117/100000: episode: 120, duration: 0.042s, episode steps: 31, steps per second: 736, episode reward: 31.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.323 [0.000, 1.000], mean observation: -0.021 [-2.080, 2.744], mean_best_reward: --
#   2128/100000: episode: 121, duration: 0.016s, episode steps: 11, steps per second: 677, episode reward: 11.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.091 [0.000, 1.000], mean observation: 0.090 [-1.796, 2.741], mean_best_reward: --
#   2145/100000: episode: 122, duration: 0.021s, episode steps: 17, steps per second: 815, episode reward: 17.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.647 [0.000, 1.000], mean observation: -0.073 [-1.766, 0.975], mean_best_reward: --
#   2158/100000: episode: 123, duration: 0.018s, episode steps: 13, steps per second: 705, episode reward: 13.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.308 [0.000, 1.000], mean observation: 0.080 [-1.404, 2.035], mean_best_reward: --
#   2167/100000: episode: 124, duration: 0.015s, episode steps: 9, steps per second: 602, episode reward: 9.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.222 [0.000, 1.000], mean observation: 0.128 [-0.985, 1.757], mean_best_reward: --
#   2199/100000: episode: 125, duration: 0.043s, episode steps: 32, steps per second: 752, episode reward: 32.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.531 [0.000, 1.000], mean observation: -0.026 [-1.332, 0.965], mean_best_reward: --
#   2214/100000: episode: 126, duration: 0.024s, episode steps: 15, steps per second: 613, episode reward: 15.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.267 [0.000, 1.000], mean observation: 0.065 [-1.339, 2.080], mean_best_reward: --
#   2225/100000: episode: 127, duration: 0.017s, episode steps: 11, steps per second: 654, episode reward: 11.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.636 [0.000, 1.000], mean observation: -0.101 [-1.689, 1.018], mean_best_reward: --
#   2249/100000: episode: 128, duration: 0.031s, episode steps: 24, steps per second: 779, episode reward: 24.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.375 [0.000, 1.000], mean observation: 0.051 [-1.509, 2.254], mean_best_reward: --
#   2267/100000: episode: 129, duration: 0.023s, episode steps: 18, steps per second: 790, episode reward: 18.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.611 [0.000, 1.000], mean observation: -0.077 [-1.442, 0.957], mean_best_reward: --
#   2282/100000: episode: 130, duration: 0.020s, episode steps: 15, steps per second: 750, episode reward: 15.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.800 [0.000, 1.000], mean observation: -0.079 [-2.725, 1.737], mean_best_reward: --
#   2293/100000: episode: 131, duration: 0.016s, episode steps: 11, steps per second: 702, episode reward: 11.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.818 [0.000, 1.000], mean observation: -0.131 [-2.259, 1.355], mean_best_reward: --
#   2311/100000: episode: 132, duration: 0.023s, episode steps: 18, steps per second: 768, episode reward: 18.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.389 [0.000, 1.000], mean observation: 0.116 [-0.978, 1.874], mean_best_reward: --
#   2323/100000: episode: 133, duration: 0.017s, episode steps: 12, steps per second: 691, episode reward: 12.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.750 [0.000, 1.000], mean observation: -0.111 [-2.207, 1.402], mean_best_reward: --
#   2333/100000: episode: 134, duration: 0.015s, episode steps: 10, steps per second: 673, episode reward: 10.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.200 [0.000, 1.000], mean observation: 0.124 [-1.348, 2.158], mean_best_reward: --
#   2342/100000: episode: 135, duration: 0.016s, episode steps: 9, steps per second: 565, episode reward: 9.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.889 [0.000, 1.000], mean observation: -0.156 [-2.334, 1.359], mean_best_reward: --
#   2354/100000: episode: 136, duration: 0.018s, episode steps: 12, steps per second: 672, episode reward: 12.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.333 [0.000, 1.000], mean observation: 0.098 [-1.026, 1.693], mean_best_reward: --
#   2369/100000: episode: 137, duration: 0.021s, episode steps: 15, steps per second: 709, episode reward: 15.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.733 [0.000, 1.000], mean observation: -0.119 [-2.465, 1.384], mean_best_reward: --
#   2396/100000: episode: 138, duration: 0.035s, episode steps: 27, steps per second: 781, episode reward: 27.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.481 [0.000, 1.000], mean observation: 0.074 [-0.764, 1.314], mean_best_reward: --
#   2405/100000: episode: 139, duration: 0.015s, episode steps: 9, steps per second: 611, episode reward: 9.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.000 [0.000, 0.000], mean observation: 0.145 [-1.806, 2.836], mean_best_reward: --
#   2417/100000: episode: 140, duration: 0.017s, episode steps: 12, steps per second: 709, episode reward: 12.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.750 [0.000, 1.000], mean observation: -0.125 [-2.064, 1.186], mean_best_reward: --
#   2427/100000: episode: 141, duration: 0.016s, episode steps: 10, steps per second: 622, episode reward: 10.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.900 [0.000, 1.000], mean observation: -0.134 [-2.511, 1.546], mean_best_reward: --
#   2437/100000: episode: 142, duration: 0.016s, episode steps: 10, steps per second: 645, episode reward: 10.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.800 [0.000, 1.000], mean observation: -0.150 [-2.314, 1.362], mean_best_reward: --
#   2449/100000: episode: 143, duration: 0.018s, episode steps: 12, steps per second: 684, episode reward: 12.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.333 [0.000, 1.000], mean observation: 0.140 [-0.942, 1.784], mean_best_reward: --
#   2459/100000: episode: 144, duration: 0.017s, episode steps: 10, steps per second: 575, episode reward: 10.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.800 [0.000, 1.000], mean observation: -0.122 [-1.902, 1.154], mean_best_reward: --
#   2471/100000: episode: 145, duration: 0.018s, episode steps: 12, steps per second: 672, episode reward: 12.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.917 [0.000, 1.000], mean observation: -0.105 [-3.019, 1.974], mean_best_reward: --
#   2481/100000: episode: 146, duration: 0.014s, episode steps: 10, steps per second: 704, episode reward: 10.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.800 [0.000, 1.000], mean observation: -0.151 [-2.288, 1.354], mean_best_reward: --
#   2500/100000: episode: 147, duration: 0.024s, episode steps: 19, steps per second: 804, episode reward: 19.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.526 [0.000, 1.000], mean observation: -0.105 [-1.025, 0.557], mean_best_reward: --
#   2522/100000: episode: 148, duration: 0.030s, episode steps: 22, steps per second: 744, episode reward: 22.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.409 [0.000, 1.000], mean observation: 0.083 [-0.794, 1.557], mean_best_reward: --
#   2537/100000: episode: 149, duration: 0.020s, episode steps: 15, steps per second: 747, episode reward: 15.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.133 [0.000, 1.000], mean observation: 0.095 [-2.141, 3.250], mean_best_reward: --
#   2555/100000: episode: 150, duration: 0.023s, episode steps: 18, steps per second: 796, episode reward: 18.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.444 [0.000, 1.000], mean observation: 0.069 [-0.792, 1.185], mean_best_reward: --
#   2570/100000: episode: 151, duration: 0.021s, episode steps: 15, steps per second: 721, episode reward: 15.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.400 [0.000, 1.000], mean observation: 0.097 [-0.791, 1.449], mean_best_reward: 48.000000
#   2588/100000: episode: 152, duration: 0.023s, episode steps: 18, steps per second: 782, episode reward: 18.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.611 [0.000, 1.000], mean observation: -0.096 [-1.908, 1.131], mean_best_reward: --
#   2601/100000: episode: 153, duration: 0.020s, episode steps: 13, steps per second: 651, episode reward: 13.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.615 [0.000, 1.000], mean observation: -0.095 [-1.476, 0.984], mean_best_reward: --
#   2612/100000: episode: 154, duration: 0.016s, episode steps: 11, steps per second: 668, episode reward: 11.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.091 [0.000, 1.000], mean observation: 0.111 [-1.785, 2.766], mean_best_reward: --
#   2624/100000: episode: 155, duration: 0.017s, episode steps: 12, steps per second: 695, episode reward: 12.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.333 [0.000, 1.000], mean observation: 0.117 [-0.782, 1.481], mean_best_reward: --
#   2633/100000: episode: 156, duration: 0.015s, episode steps: 9, steps per second: 596, episode reward: 9.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.889 [0.000, 1.000], mean observation: -0.143 [-2.257, 1.354], mean_best_reward: --
#   2641/100000: episode: 157, duration: 0.013s, episode steps: 8, steps per second: 593, episode reward: 8.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.250 [0.000, 1.000], mean observation: 0.129 [-1.198, 1.930], mean_best_reward: --
#   2651/100000: episode: 158, duration: 0.015s, episode steps: 10, steps per second: 669, episode reward: 10.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.700 [0.000, 1.000], mean observation: -0.119 [-1.643, 0.990], mean_best_reward: --
#   2662/100000: episode: 159, duration: 0.015s, episode steps: 11, steps per second: 710, episode reward: 11.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.364 [0.000, 1.000], mean observation: 0.121 [-0.955, 1.683], mean_best_reward: --
#   2675/100000: episode: 160, duration: 0.018s, episode steps: 13, steps per second: 706, episode reward: 13.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.846 [0.000, 1.000], mean observation: -0.096 [-2.858, 1.814], mean_best_reward: --
#   2728/100000: episode: 161, duration: 0.061s, episode steps: 53, steps per second: 863, episode reward: 53.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.528 [0.000, 1.000], mean observation: 0.174 [-0.527, 0.976], mean_best_reward: --
#   2754/100000: episode: 162, duration: 0.035s, episode steps: 26, steps per second: 747, episode reward: 26.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.500 [0.000, 1.000], mean observation: 0.135 [-0.375, 1.157], mean_best_reward: --
#   2769/100000: episode: 163, duration: 0.020s, episode steps: 15, steps per second: 747, episode reward: 15.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.200 [0.000, 1.000], mean observation: 0.109 [-1.803, 2.887], mean_best_reward: --
#   2789/100000: episode: 164, duration: 0.027s, episode steps: 20, steps per second: 744, episode reward: 20.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.750 [0.000, 1.000], mean observation: -0.013 [-2.986, 2.158], mean_best_reward: --
#   2802/100000: episode: 165, duration: 0.018s, episode steps: 13, steps per second: 741, episode reward: 13.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.692 [0.000, 1.000], mean observation: -0.114 [-1.744, 0.961], mean_best_reward: --
#   2815/100000: episode: 166, duration: 0.018s, episode steps: 13, steps per second: 707, episode reward: 13.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.846 [0.000, 1.000], mean observation: -0.118 [-2.802, 1.712], mean_best_reward: --
#   2831/100000: episode: 167, duration: 0.022s, episode steps: 16, steps per second: 726, episode reward: 16.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.688 [0.000, 1.000], mean observation: -0.096 [-2.083, 1.195], mean_best_reward: --
#   2847/100000: episode: 168, duration: 0.025s, episode steps: 16, steps per second: 632, episode reward: 16.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.312 [0.000, 1.000], mean observation: 0.103 [-1.139, 2.028], mean_best_reward: --
#   2857/100000: episode: 169, duration: 0.014s, episode steps: 10, steps per second: 692, episode reward: 10.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.800 [0.000, 1.000], mean observation: -0.146 [-2.270, 1.366], mean_best_reward: --
#   2867/100000: episode: 170, duration: 0.019s, episode steps: 10, steps per second: 530, episode reward: 10.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.900 [0.000, 1.000], mean observation: -0.117 [-2.526, 1.588], mean_best_reward: --
#   2879/100000: episode: 171, duration: 0.020s, episode steps: 12, steps per second: 609, episode reward: 12.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.250 [0.000, 1.000], mean observation: 0.101 [-1.218, 2.007], mean_best_reward: --
#   2895/100000: episode: 172, duration: 0.027s, episode steps: 16, steps per second: 593, episode reward: 16.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.375 [0.000, 1.000], mean observation: 0.122 [-0.953, 1.836], mean_best_reward: --
#   2918/100000: episode: 173, duration: 0.034s, episode steps: 23, steps per second: 668, episode reward: 23.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.478 [0.000, 1.000], mean observation: -0.087 [-0.912, 0.266], mean_best_reward: --
#   2936/100000: episode: 174, duration: 0.028s, episode steps: 18, steps per second: 652, episode reward: 18.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.667 [0.000, 1.000], mean observation: -0.093 [-2.188, 1.320], mean_best_reward: --
#   2958/100000: episode: 175, duration: 0.032s, episode steps: 22, steps per second: 688, episode reward: 22.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.636 [0.000, 1.000], mean observation: -0.053 [-2.184, 1.396], mean_best_reward: --
#   2974/100000: episode: 176, duration: 0.024s, episode steps: 16, steps per second: 662, episode reward: 16.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.375 [0.000, 1.000], mean observation: 0.064 [-1.190, 1.680], mean_best_reward: --
#   2986/100000: episode: 177, duration: 0.021s, episode steps: 12, steps per second: 583, episode reward: 12.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.750 [0.000, 1.000], mean observation: -0.095 [-2.023, 1.198], mean_best_reward: --
#   2994/100000: episode: 178, duration: 0.014s, episode steps: 8, steps per second: 573, episode reward: 8.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.000 [0.000, 0.000], mean observation: 0.145 [-1.581, 2.541], mean_best_reward: --
#   3010/100000: episode: 179, duration: 0.028s, episode steps: 16, steps per second: 568, episode reward: 16.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.750 [0.000, 1.000], mean observation: -0.077 [-2.675, 1.753], mean_best_reward: --
#   3021/100000: episode: 180, duration: 0.018s, episode steps: 11, steps per second: 628, episode reward: 11.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.818 [0.000, 1.000], mean observation: -0.114 [-2.380, 1.392], mean_best_reward: --
#   3039/100000: episode: 181, duration: 0.028s, episode steps: 18, steps per second: 647, episode reward: 18.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.444 [0.000, 1.000], mean observation: 0.089 [-0.759, 1.284], mean_best_reward: --
#   3054/100000: episode: 182, duration: 0.022s, episode steps: 15, steps per second: 691, episode reward: 15.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.667 [0.000, 1.000], mean observation: -0.120 [-1.879, 0.957], mean_best_reward: --
#   3064/100000: episode: 183, duration: 0.016s, episode steps: 10, steps per second: 631, episode reward: 10.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.900 [0.000, 1.000], mean observation: -0.125 [-2.581, 1.552], mean_best_reward: --
#   3072/100000: episode: 184, duration: 0.014s, episode steps: 8, steps per second: 571, episode reward: 8.000, mean reward: 1.000 [1.000, 1.000], mean action: 1.000 [1.000, 1.000], mean observation: -0.163 [-2.559, 1.518], mean_best_reward: --
#   3086/100000: episode: 185, duration: 0.023s, episode steps: 14, steps per second: 620, episode reward: 14.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.714 [0.000, 1.000], mean observation: -0.085 [-2.005, 1.197], mean_best_reward: --
#   3114/100000: episode: 186, duration: 0.042s, episode steps: 28, steps per second: 668, episode reward: 28.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.643 [0.000, 1.000], mean observation: -0.053 [-2.550, 1.566], mean_best_reward: --
#   3184/100000: episode: 187, duration: 0.088s, episode steps: 70, steps per second: 792, episode reward: 70.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.514 [0.000, 1.000], mean observation: 0.013 [-0.571, 0.888], mean_best_reward: --
#   3197/100000: episode: 188, duration: 0.018s, episode steps: 13, steps per second: 705, episode reward: 13.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.769 [0.000, 1.000], mean observation: -0.123 [-2.342, 1.336], mean_best_reward: --
#   3206/100000: episode: 189, duration: 0.016s, episode steps: 9, steps per second: 577, episode reward: 9.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.222 [0.000, 1.000], mean observation: 0.140 [-1.005, 1.748], mean_best_reward: --
# ...
#  96168/100000: episode: 2298, duration: 0.085s, episode steps: 68, steps per second: 802, episode reward: 68.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.485 [0.000, 1.000], mean observation: -0.004 [-0.986, 0.876], mean_best_reward: --
#  96270/100000: episode: 2299, duration: 0.128s, episode steps: 102, steps per second: 794, episode reward: 102.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.529 [0.000, 1.000], mean observation: 0.126 [-1.239, 1.558], mean_best_reward: --
#  96382/100000: episode: 2300, duration: 0.133s, episode steps: 112, steps per second: 845, episode reward: 112.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.518 [0.000, 1.000], mean observation: 0.150 [-0.812, 0.998], mean_best_reward: --
#  96404/100000: episode: 2301, duration: 0.029s, episode steps: 22, steps per second: 755, episode reward: 22.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.364 [0.000, 1.000], mean observation: 0.033 [-1.174, 1.881], mean_best_reward: 143.500000
#  96465/100000: episode: 2302, duration: 0.073s, episode steps: 61, steps per second: 840, episode reward: 61.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.475 [0.000, 1.000], mean observation: -0.133 [-1.303, 0.693], mean_best_reward: --
#  96495/100000: episode: 2303, duration: 0.035s, episode steps: 30, steps per second: 859, episode reward: 30.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.500 [0.000, 1.000], mean observation: 0.076 [-0.452, 1.119], mean_best_reward: --
#  96579/100000: episode: 2304, duration: 0.094s, episode steps: 84, steps per second: 893, episode reward: 84.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.512 [0.000, 1.000], mean observation: 0.050 [-0.813, 1.071], mean_best_reward: --
#  96608/100000: episode: 2305, duration: 0.036s, episode steps: 29, steps per second: 795, episode reward: 29.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.483 [0.000, 1.000], mean observation: 0.055 [-0.592, 1.141], mean_best_reward: --
#  96627/100000: episode: 2306, duration: 0.024s, episode steps: 19, steps per second: 781, episode reward: 19.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.579 [0.000, 1.000], mean observation: -0.094 [-1.710, 0.821], mean_best_reward: --
#  96642/100000: episode: 2307, duration: 0.022s, episode steps: 15, steps per second: 669, episode reward: 15.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.533 [0.000, 1.000], mean observation: -0.096 [-1.346, 0.789], mean_best_reward: --
#  96678/100000: episode: 2308, duration: 0.045s, episode steps: 36, steps per second: 802, episode reward: 36.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.472 [0.000, 1.000], mean observation: -0.170 [-1.126, 0.581], mean_best_reward: --
#  96735/100000: episode: 2309, duration: 0.068s, episode steps: 57, steps per second: 840, episode reward: 57.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.509 [0.000, 1.000], mean observation: 0.048 [-0.593, 0.845], mean_best_reward: --
#  96751/100000: episode: 2310, duration: 0.020s, episode steps: 16, steps per second: 782, episode reward: 16.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.500 [0.000, 1.000], mean observation: 0.088 [-0.609, 0.959], mean_best_reward: --
#  96778/100000: episode: 2311, duration: 0.034s, episode steps: 27, steps per second: 803, episode reward: 27.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.481 [0.000, 1.000], mean observation: -0.125 [-1.312, 0.776], mean_best_reward: --
#  96811/100000: episode: 2312, duration: 0.042s, episode steps: 33, steps per second: 777, episode reward: 33.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.485 [0.000, 1.000], mean observation: 0.104 [-0.405, 1.320], mean_best_reward: --
#  96847/100000: episode: 2313, duration: 0.045s, episode steps: 36, steps per second: 800, episode reward: 36.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.472 [0.000, 1.000], mean observation: 0.044 [-0.968, 1.537], mean_best_reward: --
#  96988/100000: episode: 2314, duration: 0.159s, episode steps: 141, steps per second: 884, episode reward: 141.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.511 [0.000, 1.000], mean observation: 0.014 [-1.029, 1.148], mean_best_reward: --
#  97049/100000: episode: 2315, duration: 0.075s, episode steps: 61, steps per second: 810, episode reward: 61.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.475 [0.000, 1.000], mean observation: -0.089 [-1.395, 0.800], mean_best_reward: --
#  97066/100000: episode: 2316, duration: 0.023s, episode steps: 17, steps per second: 747, episode reward: 17.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.588 [0.000, 1.000], mean observation: -0.061 [-1.442, 0.999], mean_best_reward: --
#  97106/100000: episode: 2317, duration: 0.049s, episode steps: 40, steps per second: 809, episode reward: 40.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.500 [0.000, 1.000], mean observation: 0.002 [-1.116, 1.435], mean_best_reward: --
#  97174/100000: episode: 2318, duration: 0.088s, episode steps: 68, steps per second: 777, episode reward: 68.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.515 [0.000, 1.000], mean observation: 0.028 [-0.636, 1.040], mean_best_reward: --
#  97188/100000: episode: 2319, duration: 0.020s, episode steps: 14, steps per second: 687, episode reward: 14.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.429 [0.000, 1.000], mean observation: 0.102 [-0.818, 1.308], mean_best_reward: --
#  97232/100000: episode: 2320, duration: 0.052s, episode steps: 44, steps per second: 850, episode reward: 44.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.545 [0.000, 1.000], mean observation: -0.028 [-1.680, 0.847], mean_best_reward: --
#  97275/100000: episode: 2321, duration: 0.051s, episode steps: 43, steps per second: 850, episode reward: 43.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.465 [0.000, 1.000], mean observation: 0.036 [-0.730, 1.391], mean_best_reward: --
#  97373/100000: episode: 2322, duration: 0.111s, episode steps: 98, steps per second: 884, episode reward: 98.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.490 [0.000, 1.000], mean observation: -0.238 [-1.678, 1.107], mean_best_reward: --
#  97457/100000: episode: 2323, duration: 0.099s, episode steps: 84, steps per second: 853, episode reward: 84.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.476 [0.000, 1.000], mean observation: -0.218 [-1.701, 1.126], mean_best_reward: --
#  97613/100000: episode: 2324, duration: 0.177s, episode steps: 156, steps per second: 882, episode reward: 156.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.494 [0.000, 1.000], mean observation: 0.186 [-1.043, 1.462], mean_best_reward: --
#  97663/100000: episode: 2325, duration: 0.058s, episode steps: 50, steps per second: 857, episode reward: 50.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.460 [0.000, 1.000], mean observation: -0.125 [-0.984, 0.435], mean_best_reward: --
#  97673/100000: episode: 2326, duration: 0.016s, episode steps: 10, steps per second: 632, episode reward: 10.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.400 [0.000, 1.000], mean observation: 0.142 [-0.773, 1.350], mean_best_reward: --
#  97829/100000: episode: 2327, duration: 0.175s, episode steps: 156, steps per second: 891, episode reward: 156.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.494 [0.000, 1.000], mean observation: 0.028 [-1.056, 0.933], mean_best_reward: --
#  98028/100000: episode: 2328, duration: 0.240s, episode steps: 199, steps per second: 828, episode reward: 199.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.503 [0.000, 1.000], mean observation: -0.050 [-2.048, 1.341], mean_best_reward: --
#  98080/100000: episode: 2329, duration: 0.061s, episode steps: 52, steps per second: 854, episode reward: 52.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.462 [0.000, 1.000], mean observation: -0.023 [-1.133, 1.406], mean_best_reward: --
#  98102/100000: episode: 2330, duration: 0.027s, episode steps: 22, steps per second: 811, episode reward: 22.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.500 [0.000, 1.000], mean observation: 0.070 [-0.651, 1.269], mean_best_reward: --
#  98120/100000: episode: 2331, duration: 0.024s, episode steps: 18, steps per second: 759, episode reward: 18.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.500 [0.000, 1.000], mean observation: -0.102 [-1.072, 0.569], mean_best_reward: --
#  98139/100000: episode: 2332, duration: 0.025s, episode steps: 19, steps per second: 763, episode reward: 19.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.368 [0.000, 1.000], mean observation: 0.034 [-1.402, 2.041], mean_best_reward: --
#  98297/100000: episode: 2333, duration: 0.174s, episode steps: 158, steps per second: 906, episode reward: 158.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.506 [0.000, 1.000], mean observation: 0.028 [-0.886, 1.109], mean_best_reward: --
#  98411/100000: episode: 2334, duration: 0.125s, episode steps: 114, steps per second: 909, episode reward: 114.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.500 [0.000, 1.000], mean observation: 0.138 [-0.887, 1.277], mean_best_reward: --
#  98438/100000: episode: 2335, duration: 0.033s, episode steps: 27, steps per second: 821, episode reward: 27.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.481 [0.000, 1.000], mean observation: -0.117 [-1.060, 0.367], mean_best_reward: --
#  98525/100000: episode: 2336, duration: 0.101s, episode steps: 87, steps per second: 861, episode reward: 87.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.506 [0.000, 1.000], mean observation: -0.027 [-0.954, 1.143], mean_best_reward: --
#  98565/100000: episode: 2337, duration: 0.047s, episode steps: 40, steps per second: 842, episode reward: 40.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.500 [0.000, 1.000], mean observation: 0.156 [-0.356, 1.458], mean_best_reward: --
#  98670/100000: episode: 2338, duration: 0.114s, episode steps: 105, steps per second: 918, episode reward: 105.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.486 [0.000, 1.000], mean observation: 0.075 [-0.773, 2.209], mean_best_reward: --
#  98870/100000: episode: 2339, duration: 0.236s, episode steps: 200, steps per second: 848, episode reward: 200.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.495 [0.000, 1.000], mean observation: -0.194 [-1.334, 1.131], mean_best_reward: --
#  98897/100000: episode: 2340, duration: 0.035s, episode steps: 27, steps per second: 772, episode reward: 27.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.593 [0.000, 1.000], mean observation: -0.028 [-1.968, 1.361], mean_best_reward: --
#  98925/100000: episode: 2341, duration: 0.035s, episode steps: 28, steps per second: 799, episode reward: 28.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.536 [0.000, 1.000], mean observation: 0.083 [-0.576, 1.250], mean_best_reward: --
#  98993/100000: episode: 2342, duration: 0.078s, episode steps: 68, steps per second: 867, episode reward: 68.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.500 [0.000, 1.000], mean observation: -0.192 [-1.634, 0.717], mean_best_reward: --
#  99070/100000: episode: 2343, duration: 0.091s, episode steps: 77, steps per second: 847, episode reward: 77.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.506 [0.000, 1.000], mean observation: -0.011 [-1.149, 1.382], mean_best_reward: --
#  99087/100000: episode: 2344, duration: 0.021s, episode steps: 17, steps per second: 796, episode reward: 17.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.471 [0.000, 1.000], mean observation: -0.086 [-1.337, 0.815], mean_best_reward: --
#  99132/100000: episode: 2345, duration: 0.052s, episode steps: 45, steps per second: 861, episode reward: 45.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.556 [0.000, 1.000], mean observation: 0.183 [-0.471, 1.077], mean_best_reward: --
#  99210/100000: episode: 2346, duration: 0.091s, episode steps: 78, steps per second: 854, episode reward: 78.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.474 [0.000, 1.000], mean observation: -0.117 [-0.951, 0.560], mean_best_reward: --
#  99229/100000: episode: 2347, duration: 0.026s, episode steps: 19, steps per second: 742, episode reward: 19.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.579 [0.000, 1.000], mean observation: -0.093 [-1.435, 0.585], mean_best_reward: --
#  99249/100000: episode: 2348, duration: 0.028s, episode steps: 20, steps per second: 712, episode reward: 20.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.550 [0.000, 1.000], mean observation: -0.084 [-1.414, 0.745], mean_best_reward: --
#  99286/100000: episode: 2349, duration: 0.048s, episode steps: 37, steps per second: 767, episode reward: 37.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.514 [0.000, 1.000], mean observation: -0.000 [-1.442, 1.005], mean_best_reward: --
#  99306/100000: episode: 2350, duration: 0.030s, episode steps: 20, steps per second: 670, episode reward: 20.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.400 [0.000, 1.000], mean observation: 0.086 [-0.945, 1.700], mean_best_reward: --
#  99360/100000: episode: 2351, duration: 0.072s, episode steps: 54, steps per second: 747, episode reward: 54.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.426 [0.000, 1.000], mean observation: -0.287 [-1.513, 0.734], mean_best_reward: 153.500000
#  99475/100000: episode: 2352, duration: 0.145s, episode steps: 115, steps per second: 795, episode reward: 115.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.522 [0.000, 1.000], mean observation: -0.003 [-1.866, 1.321], mean_best_reward: --
#  99569/100000: episode: 2353, duration: 0.116s, episode steps: 94, steps per second: 811, episode reward: 94.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.532 [0.000, 1.000], mean observation: -0.041 [-2.182, 1.188], mean_best_reward: --
#  99610/100000: episode: 2354, duration: 0.056s, episode steps: 41, steps per second: 738, episode reward: 41.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.488 [0.000, 1.000], mean observation: 0.049 [-0.555, 1.108], mean_best_reward: --
#  99662/100000: episode: 2355, duration: 0.071s, episode steps: 52, steps per second: 736, episode reward: 52.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.538 [0.000, 1.000], mean observation: 0.099 [-0.685, 1.204], mean_best_reward: --
#  99815/100000: episode: 2356, duration: 0.180s, episode steps: 153, steps per second: 848, episode reward: 153.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.556 [0.000, 1.000], mean observation: 0.359 [-1.403, 3.203], mean_best_reward: --
#  99884/100000: episode: 2357, duration: 0.081s, episode steps: 69, steps per second: 847, episode reward: 69.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.478 [0.000, 1.000], mean observation: -0.252 [-1.591, 0.767], mean_best_reward: --
#  99899/100000: episode: 2358, duration: 0.021s, episode steps: 15, steps per second: 706, episode reward: 15.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.467 [0.000, 1.000], mean observation: -0.119 [-1.297, 0.748], mean_best_reward: --
# done, took 127.794 seconds
# Testing for 20 episodes ...
# Episode 1: reward: 141.000, steps: 141
# Episode 2: reward: 148.000, steps: 148
# Episode 3: reward: 141.000, steps: 141
# Episode 4: reward: 136.000, steps: 136
# Episode 5: reward: 140.000, steps: 140
# Episode 6: reward: 133.000, steps: 133
# Episode 7: reward: 200.000, steps: 200
# Episode 8: reward: 148.000, steps: 148
# Episode 9: reward: 141.000, steps: 141
# Episode 10: reward: 151.000, steps: 151
# Episode 11: reward: 140.000, steps: 140
# Episode 12: reward: 145.000, steps: 145
# Episode 13: reward: 144.000, steps: 144
# Episode 14: reward: 125.000, steps: 125
# Episode 15: reward: 183.000, steps: 183
# Episode 16: reward: 200.000, steps: 200
# Episode 17: reward: 140.000, steps: 140
# Episode 18: reward: 200.000, steps: 200
# Episode 19: reward: 200.000, steps: 200
# Episode 20: reward: 136.000, steps: 136
