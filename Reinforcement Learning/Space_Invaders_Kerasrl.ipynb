# %%
import argparse
import sys
from PIL import Image
import numpy as np
import gym
from keras.models import Sequential
from keras.layers import Dense, Activation, Flatten, Convolution2D, Permute
from keras.optimizers import Adam
import keras.backend as K

from rl.agents.dqn import DQNAgent
from rl.policy import LinearAnnealedPolicy, BoltzmannQPolicy, EpsGreedyQPolicy
from rl.memory import SequentialMemory
from rl.core import Processor
from rl.callbacks import FileLogger, ModelIntervalCheckpoint
# Out:
# Using TensorFlow backend.

# %%
INPUT_SHAPE = (84, 84)
WINDOW_LENGTH = 4

# %%
class AtariProcessor(Processor):
    def process_observation(self, observation):
        assert observation.ndim == 3  # (height, width, channel)
        img = Image.fromarray(observation[20:-10,:,:])
        img = img.resize((84,84)).convert('L')  # resize and convert to grayscale
        processed_observation = np.array(img)
        assert processed_observation.shape == (84,84)
        return processed_observation.astype('uint8')  # saves storage in experience memory

    def process_state_batch(self, batch):
        # We could perform this processing step in `process_observation`. In this case, however,
        # we would need to store a `float32` array instead, which is 4x more memory intensive than
        # an `uint8` array. This matters if we store 1M observations.
        processed_batch = batch.astype('float32') / 255.
        return processed_batch

    def process_reward(self, reward):
        return np.clip(reward, -1., 1.)

# %%
sys.argv = ['foo']
parser = argparse.ArgumentParser()
parser.add_argument('--mode', choices=['train', 'test'], default='train')
parser.add_argument('--env-name', type=str, default='SpaceInvaders-v0')
parser.add_argument('--weights', type=str, default=None)
args = parser.parse_args()

# Get the environment and extract the number of actions.
env = gym.make(args.env_name)
np.random.seed(123)
env.seed(123)
nb_actions = env.action_space.n

# %%
# Next, we build our model. We use the same model that was described by Mnih et al. (2015).
input_shape = (WINDOW_LENGTH,) + INPUT_SHAPE
model = Sequential()
if K.image_dim_ordering() == 'tf':
    # (width, height, channels)
    model.add(Permute((2, 3, 1), input_shape=input_shape))
elif K.image_dim_ordering() == 'th':
    # (channels, width, height)
    model.add(Permute((1, 2, 3), input_shape=input_shape))
else:
    raise RuntimeError('Unknown image_dim_ordering.')
model.add(Convolution2D(32, (8, 8), strides=(4, 4)))
model.add(Activation('relu'))
model.add(Convolution2D(64, (4, 4), strides=(2, 2)))
model.add(Activation('relu'))
model.add(Convolution2D(64, (3, 3), strides=(1, 1)))
model.add(Activation('relu'))
model.add(Flatten())
model.add(Dense(512))
model.add(Activation('relu'))
model.add(Dense(nb_actions))
model.add(Activation('linear'))
print(model.summary())

# Finally, we configure and compile our agent. You can use every built-in Keras optimizer and
# even the metrics!
memory = SequentialMemory(limit=1000000, window_length=WINDOW_LENGTH)
processor = AtariProcessor()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# permute_1 (Permute)          (None, 84, 84, 4)         0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 20, 20, 32)        8224
# _________________________________________________________________
# activation_1 (Activation)    (None, 20, 20, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 9, 9, 64)          32832
# _________________________________________________________________
# activation_2 (Activation)    (None, 9, 9, 64)          0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 7, 7, 64)          36928
# _________________________________________________________________
# activation_3 (Activation)    (None, 7, 7, 64)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 3136)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               1606144
# _________________________________________________________________
# activation_4 (Activation)    (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 6)                 3078
# _________________________________________________________________
# activation_5 (Activation)    (None, 6)                 0
# =================================================================
# Total params: 1,687,206
# Trainable params: 1,687,206
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
args.mode
# Out:
# 'train'

# %%
# Finally, we configure and compile our agent. You can use every built-in Keras optimizer and
# even the metrics!
memory = SequentialMemory(limit=1000000, window_length=WINDOW_LENGTH)
processor = AtariProcessor()

# Select a policy. We use eps-greedy action selection, which means that a random action is selected
# with probability eps. We anneal eps from 1.0 to 0.1 over the course of 1M steps. This is done so that
# the agent initially explores the environment (high eps) and then gradually sticks to what it knows
# (low eps). We also set a dedicated eps value that is used during testing. Note that we set it to 0.05
# so that the agent still performs some random actions. This ensures that the agent cannot get stuck.
policy = LinearAnnealedPolicy(EpsGreedyQPolicy(), attr='eps', value_max=1., value_min=.1, value_test=.05,
                              nb_steps=1000000)

# The trade-off between exploration and exploitation is difficult and an on-going research topic.
# If you want, you can experiment with the parameters or use a different policy. Another popular one
# is Boltzmann-style exploration:
# policy = BoltzmannQPolicy(tau=1.)
# Feel free to give it a try!

dqn = DQNAgent(model=model, nb_actions=nb_actions, policy=policy, memory=memory,
               processor=processor, nb_steps_warmup=50000, gamma=.99, target_model_update=10000,
               train_interval=4, delta_clip=1.)
dqn.compile(Adam(lr=.00025), metrics=['mae'])

if args.mode == 'train':
    # Okay, now it's time to learn something! We capture the interrupt exception so that training
    # can be prematurely aborted. Notice that now you can use the built-in Keras callbacks!
    weights_filename = 'dqn_{}_weights.h5f'.format(args.env_name)
    checkpoint_weights_filename = 'dqn_' + args.env_name + '_weights_{step}.h5f'
    log_filename = 'dqn_{}_log.json'.format(args.env_name)
    callbacks = [ModelIntervalCheckpoint(checkpoint_weights_filename, interval=250000)]
    callbacks += [FileLogger(log_filename, interval=100)]
    dqn.fit(env, callbacks=callbacks, nb_steps=1750000, log_interval=10000)

    # After training is done, we save the final weights one more time.
    dqn.save_weights(weights_filename, overwrite=True)

    # Finally, evaluate our algorithm for 10 episodes.
    dqn.test(env, nb_episodes=10, visualize=False)
elif args.mode == 'test':
    weights_filename = 'dqn_{}_weights.h5f'.format(args.env_name)
    if args.weights:
        weights_filename = args.weights
    dqn.load_weights(weights_filename)
dqn.test(env, nb_episodes=10, visualize=True)
# Out:
# Training for 1750000 steps ...
# Interval 1 (0 steps performed)
# 10000/10000 [==============================] - 30s 3ms/step - reward: 0.0133
# 16 episodes - episode_reward: 7.625 [5.000, 14.000] - ale.lives: 2.161
#
# Interval 2 (10000 steps performed)
# 10000/10000 [==============================] - 30s 3ms/step - reward: 0.0132
# 14 episodes - episode_reward: 9.214 [3.000, 20.000] - ale.lives: 2.166
#
# Interval 3 (20000 steps performed)
# 10000/10000 [==============================] - 30s 3ms/step - reward: 0.0125
# 14 episodes - episode_reward: 9.571 [2.000, 20.000] - ale.lives: 2.112
#
# Interval 4 (30000 steps performed)
# 10000/10000 [==============================] - 30s 3ms/step - reward: 0.0135
# 16 episodes - episode_reward: 8.188 [4.000, 11.000] - ale.lives: 2.174
#
# Interval 5 (40000 steps performed)
# 10000/10000 [==============================] - 30s 3ms/step - reward: 0.0128
# 14 episodes - episode_reward: 9.429 [5.000, 16.000] - ale.lives: 2.073
#
# Interval 6 (50000 steps performed)
# 10000/10000 [==============================] - 93s 9ms/step - reward: 0.0140
# 13 episodes - episode_reward: 10.846 [5.000, 16.000] - loss: 0.016 - mean_absolute_error: 2.339 - mean_q: 2.823 - mean_eps: 0.951 - ale.lives: 2.093
#
# Interval 7 (60000 steps performed)
# 10000/10000 [==============================] - 92s 9ms/step - reward: 0.0129
# 17 episodes - episode_reward: 7.765 [5.000, 17.000] - loss: 0.014 - mean_absolute_error: 2.339 - mean_q: 2.823 - mean_eps: 0.942 - ale.lives: 2.091
#
# Interval 8 (70000 steps performed)
# 10000/10000 [==============================] - 91s 9ms/step - reward: 0.0130
# 15 episodes - episode_reward: 8.533 [3.000, 24.000] - loss: 0.014 - mean_absolute_error: 2.318 - mean_q: 2.796 - mean_eps: 0.933 - ale.lives: 2.223
#
# Interval 9 (80000 steps performed)
# 10000/10000 [==============================] - 92s 9ms/step - reward: 0.0149
# 16 episodes - episode_reward: 9.500 [4.000, 19.000] - loss: 0.013 - mean_absolute_error: 2.360 - mean_q: 2.850 - mean_eps: 0.924 - ale.lives: 2.047
#
# Interval 10 (90000 steps performed)
# 10000/10000 [==============================] - 93s 9ms/step - reward: 0.0137
# 14 episodes - episode_reward: 9.429 [4.000, 17.000] - loss: 0.014 - mean_absolute_error: 2.381 - mean_q: 2.874 - mean_eps: 0.915 - ale.lives: 2.200
#
# Interval 11 (100000 steps performed)
# 10000/10000 [==============================] - 92s 9ms/step - reward: 0.0142
# 16 episodes - episode_reward: 8.875 [4.000, 17.000] - loss: 0.013 - mean_absolute_error: 2.368 - mean_q: 2.860 - mean_eps: 0.906 - ale.lives: 2.093
#
# Interval 12 (110000 steps performed)
# 10000/10000 [==============================] - 92s 9ms/step - reward: 0.0155
# 13 episodes - episode_reward: 11.308 [5.000, 19.000] - loss: 0.013 - mean_absolute_error: 2.358 - mean_q: 2.848 - mean_eps: 0.897 - ale.lives: 2.094
#
# Interval 13 (120000 steps performed)
# 10000/10000 [==============================] - 93s 9ms/step - reward: 0.0133
# 16 episodes - episode_reward: 9.062 [3.000, 24.000] - loss: 0.012 - mean_absolute_error: 2.341 - mean_q: 2.828 - mean_eps: 0.888 - ale.lives: 2.021
#
# Interval 14 (130000 steps performed)
# 10000/10000 [==============================] - 98s 10ms/step - reward: 0.0132
# 15 episodes - episode_reward: 8.333 [3.000, 16.000] - loss: 0.012 - mean_absolute_error: 2.336 - mean_q: 2.821 - mean_eps: 0.879 - ale.lives: 2.174
#
# Interval 15 (140000 steps performed)
# 10000/10000 [==============================] - 100s 10ms/step - reward: 0.0151
# 14 episodes - episode_reward: 10.714 [7.000, 20.000] - loss: 0.013 - mean_absolute_error: 2.332 - mean_q: 2.814 - mean_eps: 0.870 - ale.lives: 2.062
#
# Interval 16 (150000 steps performed)
# 10000/10000 [==============================] - 97s 10ms/step - reward: 0.0146
# 15 episodes - episode_reward: 10.133 [3.000, 21.000] - loss: 0.013 - mean_absolute_error: 2.332 - mean_q: 2.816 - mean_eps: 0.861 - ale.lives: 2.076
#
# Interval 17 (160000 steps performed)
# 10000/10000 [==============================] - 98s 10ms/step - reward: 0.0139
# 16 episodes - episode_reward: 8.688 [3.000, 15.000] - loss: 0.013 - mean_absolute_error: 2.322 - mean_q: 2.803 - mean_eps: 0.852 - ale.lives: 2.039
#
# Interval 18 (170000 steps performed)
# 10000/10000 [==============================] - 96s 10ms/step - reward: 0.0170
# 12 episodes - episode_reward: 13.667 [8.000, 21.000] - loss: 0.013 - mean_absolute_error: 2.304 - mean_q: 2.783 - mean_eps: 0.843 - ale.lives: 1.957
#
# Interval 19 (180000 steps performed)
# 10000/10000 [==============================] - 96s 10ms/step - reward: 0.0157
# 15 episodes - episode_reward: 10.800 [5.000, 16.000] - loss: 0.013 - mean_absolute_error: 2.302 - mean_q: 2.781 - mean_eps: 0.834 - ale.lives: 2.087
#
# Interval 20 (190000 steps performed)
# 10000/10000 [==============================] - 95s 10ms/step - reward: 0.0136
# 16 episodes - episode_reward: 8.188 [3.000, 15.000] - loss: 0.013 - mean_absolute_error: 2.303 - mean_q: 2.781 - mean_eps: 0.825 - ale.lives: 2.077
#
# Interval 21 (200000 steps performed)
# 10000/10000 [==============================] - 93s 9ms/step - reward: 0.0153
# 13 episodes - episode_reward: 11.615 [4.000, 18.000] - loss: 0.013 - mean_absolute_error: 2.323 - mean_q: 2.805 - mean_eps: 0.816 - ale.lives: 2.117
#
# Interval 22 (210000 steps performed)
# 10000/10000 [==============================] - 91s 9ms/step - reward: 0.0160
# 15 episodes - episode_reward: 11.067 [6.000, 19.000] - loss: 0.013 - mean_absolute_error: 2.312 - mean_q: 2.791 - mean_eps: 0.807 - ale.lives: 2.071
#
# Interval 23 (220000 steps performed)
# 10000/10000 [==============================] - 91s 9ms/step - reward: 0.0167
# 12 episodes - episode_reward: 13.833 [8.000, 21.000] - loss: 0.013 - mean_absolute_error: 2.324 - mean_q: 2.807 - mean_eps: 0.798 - ale.lives: 2.119
#
# Interval 24 (230000 steps performed)
# 10000/10000 [==============================] - 92s 9ms/step - reward: 0.0161
# 13 episodes - episode_reward: 11.846 [5.000, 24.000] - loss: 0.013 - mean_absolute_error: 2.301 - mean_q: 2.778 - mean_eps: 0.789 - ale.lives: 2.049
#
# Interval 25 (240000 steps performed)
# 10000/10000 [==============================] - 92s 9ms/step - reward: 0.0149
# 14 episodes - episode_reward: 10.929 [7.000, 18.000] - loss: 0.013 - mean_absolute_error: 2.290 - mean_q: 2.765 - mean_eps: 0.780 - ale.lives: 2.177
#
# Interval 26 (250000 steps performed)
# 10000/10000 [==============================] - 91s 9ms/step - reward: 0.0148
# 13 episodes - episode_reward: 11.692 [6.000, 21.000] - loss: 0.013 - mean_absolute_error: 2.296 - mean_q: 2.773 - mean_eps: 0.771 - ale.lives: 1.975
#
# Interval 27 (260000 steps performed)
# 10000/10000 [==============================] - 91s 9ms/step - reward: 0.0153
# 15 episodes - episode_reward: 10.000 [5.000, 15.000] - loss: 0.014 - mean_absolute_error: 2.289 - mean_q: 2.764 - mean_eps: 0.762 - ale.lives: 2.011
#
# Interval 28 (270000 steps performed)
# 10000/10000 [==============================] - 91s 9ms/step - reward: 0.0158
# 13 episodes - episode_reward: 12.077 [6.000, 21.000] - loss: 0.013 - mean_absolute_error: 2.275 - mean_q: 2.747 - mean_eps: 0.753 - ale.lives: 2.093
#
# Interval 29 (280000 steps performed)
# 10000/10000 [==============================] - 91s 9ms/step - reward: 0.0146
# 15 episodes - episode_reward: 9.800 [5.000, 19.000] - loss: 0.013 - mean_absolute_error: 2.232 - mean_q: 2.694 - mean_eps: 0.744 - ale.lives: 1.968
#
# Interval 30 (290000 steps performed)
# 10000/10000 [==============================] - 92s 9ms/step - reward: 0.0153
# 16 episodes - episode_reward: 9.812 [4.000, 15.000] - loss: 0.013 - mean_absolute_error: 2.243 - mean_q: 2.708 - mean_eps: 0.735 - ale.lives: 2.175
#
# Interval 31 (300000 steps performed)
# 10000/10000 [==============================] - 92s 9ms/step - reward: 0.0157
# 15 episodes - episode_reward: 10.200 [7.000, 18.000] - loss: 0.013 - mean_absolute_error: 2.229 - mean_q: 2.690 - mean_eps: 0.726 - ale.lives: 2.134
#
# Interval 32 (310000 steps performed)
# 10000/10000 [==============================] - 92s 9ms/step - reward: 0.0158
# 14 episodes - episode_reward: 11.571 [6.000, 21.000] - loss: 0.013 - mean_absolute_error: 2.238 - mean_q: 2.700 - mean_eps: 0.717 - ale.lives: 2.090
#
# Interval 33 (320000 steps performed)
# 10000/10000 [==============================] - 92s 9ms/step - reward: 0.0165
# 14 episodes - episode_reward: 11.500 [6.000, 19.000] - loss: 0.013 - mean_absolute_error: 2.218 - mean_q: 2.677 - mean_eps: 0.708 - ale.lives: 2.038
#
# Interval 34 (330000 steps performed)
# 10000/10000 [==============================] - 94s 9ms/step - reward: 0.0167
# 14 episodes - episode_reward: 12.500 [5.000, 31.000] - loss: 0.013 - mean_absolute_error: 2.228 - mean_q: 2.688 - mean_eps: 0.699 - ale.lives: 2.070
#
# Interval 35 (340000 steps performed)
# 10000/10000 [==============================] - 93s 9ms/step - reward: 0.0164
# 15 episodes - episode_reward: 10.133 [5.000, 16.000] - loss: 0.013 - mean_absolute_error: 2.240 - mean_q: 2.704 - mean_eps: 0.690 - ale.lives: 2.059
#
# Interval 36 (350000 steps performed)
# 10000/10000 [==============================] - 92s 9ms/step - reward: 0.0149
# 15 episodes - episode_reward: 10.733 [4.000, 19.000] - loss: 0.013 - mean_absolute_error: 2.237 - mean_q: 2.699 - mean_eps: 0.681 - ale.lives: 2.045
#
# Interval 37 (360000 steps performed)
# 10000/10000 [==============================] - 93s 9ms/step - reward: 0.0170
# 14 episodes - episode_reward: 11.357 [5.000, 24.000] - loss: 0.013 - mean_absolute_error: 2.256 - mean_q: 2.723 - mean_eps: 0.672 - ale.lives: 1.936
#
# Interval 38 (370000 steps performed)
# 10000/10000 [==============================] - 94s 9ms/step - reward: 0.0168
# 16 episodes - episode_reward: 10.625 [5.000, 26.000] - loss: 0.013 - mean_absolute_error: 2.273 - mean_q: 2.743 - mean_eps: 0.663 - ale.lives: 2.104
#
# Interval 39 (380000 steps performed)
# 10000/10000 [==============================] - 95s 9ms/step - reward: 0.0172
# 14 episodes - episode_reward: 12.500 [7.000, 23.000] - loss: 0.013 - mean_absolute_error: 2.261 - mean_q: 2.731 - mean_eps: 0.654 - ale.lives: 2.062
#
# Interval 40 (390000 steps performed)
# 10000/10000 [==============================] - 95s 9ms/step - reward: 0.0164
# 16 episodes - episode_reward: 9.938 [4.000, 16.000] - loss: 0.014 - mean_absolute_error: 2.277 - mean_q: 2.748 - mean_eps: 0.645 - ale.lives: 2.158
#
# Interval 41 (400000 steps performed)
# 10000/10000 [==============================] - 95s 9ms/step - reward: 0.0166
# 16 episodes - episode_reward: 10.875 [4.000, 24.000] - loss: 0.013 - mean_absolute_error: 2.221 - mean_q: 2.680 - mean_eps: 0.636 - ale.lives: 2.129
#
# Interval 42 (410000 steps performed)
# 10000/10000 [==============================] - 92s 9ms/step - reward: 0.0185
# 14 episodes - episode_reward: 12.714 [4.000, 29.000] - loss: 0.013 - mean_absolute_error: 2.187 - mean_q: 2.639 - mean_eps: 0.627 - ale.lives: 1.998
#
# Interval 43 (420000 steps performed)
# 10000/10000 [==============================] - 94s 9ms/step - reward: 0.0173
# 16 episodes - episode_reward: 10.938 [4.000, 23.000] - loss: 0.013 - mean_absolute_error: 2.166 - mean_q: 2.613 - mean_eps: 0.618 - ale.lives: 2.170
#
# Interval 44 (430000 steps performed)
# 10000/10000 [==============================] - 96s 10ms/step - reward: 0.0181
# 16 episodes - episode_reward: 11.750 [4.000, 32.000] - loss: 0.013 - mean_absolute_error: 2.157 - mean_q: 2.603 - mean_eps: 0.609 - ale.lives: 2.096
#
# Interval 45 (440000 steps performed)
# 10000/10000 [==============================] - 96s 10ms/step - reward: 0.0178
# 16 episodes - episode_reward: 10.688 [5.000, 16.000] - loss: 0.013 - mean_absolute_error: 2.138 - mean_q: 2.579 - mean_eps: 0.600 - ale.lives: 2.130
#
# Interval 46 (450000 steps performed)
# 10000/10000 [==============================] - 96s 10ms/step - reward: 0.0174
# 14 episodes - episode_reward: 12.429 [4.000, 22.000] - loss: 0.012 - mean_absolute_error: 2.129 - mean_q: 2.567 - mean_eps: 0.591 - ale.lives: 2.124
#
# Interval 47 (460000 steps performed)
# 10000/10000 [==============================] - 93s 9ms/step - reward: 0.0165
# 16 episodes - episode_reward: 10.125 [4.000, 19.000] - loss: 0.013 - mean_absolute_error: 2.166 - mean_q: 2.612 - mean_eps: 0.582 - ale.lives: 2.154
#
# Interval 48 (470000 steps performed)
# 10000/10000 [==============================] - 94s 9ms/step - reward: 0.0180
# 15 episodes - episode_reward: 12.667 [4.000, 23.000] - loss: 0.013 - mean_absolute_error: 2.173 - mean_q: 2.621 - mean_eps: 0.573 - ale.lives: 2.260
#
# Interval 49 (480000 steps performed)
# 10000/10000 [==============================] - 95s 10ms/step - reward: 0.0175
# 14 episodes - episode_reward: 12.429 [6.000, 35.000] - loss: 0.014 - mean_absolute_error: 2.186 - mean_q: 2.637 - mean_eps: 0.564 - ale.lives: 2.250
#
# Interval 50 (490000 steps performed)
# 10000/10000 [==============================] - 94s 9ms/step - reward: 0.0161
# 15 episodes - episode_reward: 10.867 [5.000, 29.000] - loss: 0.014 - mean_absolute_error: 2.192 - mean_q: 2.644 - mean_eps: 0.555 - ale.lives: 1.936
#
# Interval 51 (500000 steps performed)
# 10000/10000 [==============================] - 93s 9ms/step - reward: 0.0190
# 13 episodes - episode_reward: 14.615 [8.000, 26.000] - loss: 0.013 - mean_absolute_error: 2.211 - mean_q: 2.669 - mean_eps: 0.546 - ale.lives: 2.182
#
# Interval 52 (510000 steps performed)
# 10000/10000 [==============================] - 93s 9ms/step - reward: 0.0159
# 14 episodes - episode_reward: 11.143 [2.000, 21.000] - loss: 0.013 - mean_absolute_error: 2.206 - mean_q: 2.662 - mean_eps: 0.537 - ale.lives: 2.217
#
# Interval 53 (520000 steps performed)
# 10000/10000 [==============================] - 95s 10ms/step - reward: 0.0164
# 14 episodes - episode_reward: 11.286 [4.000, 26.000] - loss: 0.013 - mean_absolute_error: 2.185 - mean_q: 2.635 - mean_eps: 0.528 - ale.lives: 2.065
#
# Interval 54 (530000 steps performed)
# 10000/10000 [==============================] - 95s 9ms/step - reward: 0.0181
# 14 episodes - episode_reward: 12.714 [7.000, 22.000] - loss: 0.013 - mean_absolute_error: 2.176 - mean_q: 2.623 - mean_eps: 0.519 - ale.lives: 1.965
#
# Interval 55 (540000 steps performed)
# 10000/10000 [==============================] - 93s 9ms/step - reward: 0.0188
# 12 episodes - episode_reward: 16.250 [8.000, 29.000] - loss: 0.013 - mean_absolute_error: 2.170 - mean_q: 2.618 - mean_eps: 0.510 - ale.lives: 2.057
#
# Interval 56 (550000 steps performed)
# 10000/10000 [==============================] - 95s 9ms/step - reward: 0.0187
# 12 episodes - episode_reward: 15.667 [4.000, 25.000] - loss: 0.013 - mean_absolute_error: 2.196 - mean_q: 2.650 - mean_eps: 0.501 - ale.lives: 2.051
#
# Interval 57 (560000 steps performed)
# 10000/10000 [==============================] - 96s 10ms/step - reward: 0.0199
# 14 episodes - episode_reward: 14.500 [3.000, 28.000] - loss: 0.014 - mean_absolute_error: 2.185 - mean_q: 2.635 - mean_eps: 0.492 - ale.lives: 1.910
#
# Interval 58 (570000 steps performed)
# 10000/10000 [==============================] - 96s 10ms/step - reward: 0.0165
# 13 episodes - episode_reward: 12.308 [5.000, 24.000] - loss: 0.013 - mean_absolute_error: 2.162 - mean_q: 2.607 - mean_eps: 0.483 - ale.lives: 2.155
#
# Interval 59 (580000 steps performed)
# 10000/10000 [==============================] - 95s 9ms/step - reward: 0.0164
# 15 episodes - episode_reward: 10.733 [4.000, 18.000] - loss: 0.013 - mean_absolute_error: 2.172 - mean_q: 2.619 - mean_eps: 0.474 - ale.lives: 2.149
#
# Interval 60 (590000 steps performed)
# 10000/10000 [==============================] - 97s 10ms/step - reward: 0.0155
# 15 episodes - episode_reward: 10.467 [5.000, 19.000] - loss: 0.013 - mean_absolute_error: 2.190 - mean_q: 2.643 - mean_eps: 0.465 - ale.lives: 2.197
#
# Interval 61 (600000 steps performed)
# 10000/10000 [==============================] - 95s 9ms/step - reward: 0.0182
# 11 episodes - episode_reward: 16.364 [7.000, 26.000] - loss: 0.013 - mean_absolute_error: 2.202 - mean_q: 2.657 - mean_eps: 0.456 - ale.lives: 2.174
#
# Interval 62 (610000 steps performed)
# 10000/10000 [==============================] - 95s 9ms/step - reward: 0.0198
# 13 episodes - episode_reward: 15.231 [7.000, 26.000] - loss: 0.014 - mean_absolute_error: 2.234 - mean_q: 2.696 - mean_eps: 0.447 - ale.lives: 2.155
#
# Interval 63 (620000 steps performed)
# 10000/10000 [==============================] - 95s 9ms/step - reward: 0.0175
# 14 episodes - episode_reward: 12.286 [7.000, 24.000] - loss: 0.013 - mean_absolute_error: 2.223 - mean_q: 2.681 - mean_eps: 0.438 - ale.lives: 2.150
#
# Interval 64 (630000 steps performed)
# 10000/10000 [==============================] - 95s 10ms/step - reward: 0.0173
# 13 episodes - episode_reward: 13.538 [1.000, 23.000] - loss: 0.014 - mean_absolute_error: 2.245 - mean_q: 2.709 - mean_eps: 0.429 - ale.lives: 2.141
#
# Interval 65 (640000 steps performed)
# 10000/10000 [==============================] - 95s 10ms/step - reward: 0.0194
# 12 episodes - episode_reward: 16.083 [3.000, 30.000] - loss: 0.014 - mean_absolute_error: 2.264 - mean_q: 2.730 - mean_eps: 0.420 - ale.lives: 2.130
#
# Interval 66 (650000 steps performed)
# 10000/10000 [==============================] - 95s 10ms/step - reward: 0.0181
# 12 episodes - episode_reward: 15.833 [5.000, 24.000] - loss: 0.014 - mean_absolute_error: 2.267 - mean_q: 2.735 - mean_eps: 0.411 - ale.lives: 2.259
#
# Interval 67 (660000 steps performed)
# 10000/10000 [==============================] - 94s 9ms/step - reward: 0.0182
# 12 episodes - episode_reward: 14.583 [6.000, 21.000] - loss: 0.015 - mean_absolute_error: 2.256 - mean_q: 2.722 - mean_eps: 0.402 - ale.lives: 2.028
#
# Interval 68 (670000 steps performed)
# 10000/10000 [==============================] - 96s 10ms/step - reward: 0.0185
# 15 episodes - episode_reward: 12.600 [4.000, 19.000] - loss: 0.014 - mean_absolute_error: 2.251 - mean_q: 2.716 - mean_eps: 0.393 - ale.lives: 2.117
#
# Interval 69 (680000 steps performed)
# 10000/10000 [==============================] - 96s 10ms/step - reward: 0.0170
# 14 episodes - episode_reward: 11.714 [3.000, 20.000] - loss: 0.014 - mean_absolute_error: 2.263 - mean_q: 2.731 - mean_eps: 0.384 - ale.lives: 2.157
#
# Interval 70 (690000 steps performed)
# 10000/10000 [==============================] - 95s 10ms/step - reward: 0.0206
# 14 episodes - episode_reward: 14.643 [6.000, 27.000] - loss: 0.014 - mean_absolute_error: 2.249 - mean_q: 2.713 - mean_eps: 0.375 - ale.lives: 2.159
#
# Interval 71 (700000 steps performed)
# 10000/10000 [==============================] - 95s 10ms/step - reward: 0.0187
# 14 episodes - episode_reward: 13.786 [6.000, 23.000] - loss: 0.015 - mean_absolute_error: 2.247 - mean_q: 2.709 - mean_eps: 0.366 - ale.lives: 2.155
#
# Interval 72 (710000 steps performed)
# 10000/10000 [==============================] - 96s 10ms/step - reward: 0.0197
# 11 episodes - episode_reward: 16.273 [5.000, 33.000] - loss: 0.014 - mean_absolute_error: 2.255 - mean_q: 2.720 - mean_eps: 0.357 - ale.lives: 2.154
#
# Interval 73 (720000 steps performed)
# 10000/10000 [==============================] - 94s 9ms/step - reward: 0.0162
# 15 episodes - episode_reward: 11.600 [3.000, 25.000] - loss: 0.014 - mean_absolute_error: 2.261 - mean_q: 2.728 - mean_eps: 0.348 - ale.lives: 2.086
#
# Interval 74 (730000 steps performed)
# 10000/10000 [==============================] - 96s 10ms/step - reward: 0.0189
# 14 episodes - episode_reward: 13.929 [6.000, 29.000] - loss: 0.015 - mean_absolute_error: 2.283 - mean_q: 2.754 - mean_eps: 0.339 - ale.lives: 2.046
#
# Interval 75 (740000 steps performed)
# 10000/10000 [==============================] - 96s 10ms/step - reward: 0.0192
# 11 episodes - episode_reward: 16.364 [7.000, 30.000] - loss: 0.014 - mean_absolute_error: 2.294 - mean_q: 2.766 - mean_eps: 0.330 - ale.lives: 2.010
#
# Interval 76 (750000 steps performed)
# 10000/10000 [==============================] - 96s 10ms/step - reward: 0.0187
# 14 episodes - episode_reward: 14.500 [6.000, 25.000] - loss: 0.015 - mean_absolute_error: 2.286 - mean_q: 2.757 - mean_eps: 0.321 - ale.lives: 1.973
#
# Interval 77 (760000 steps performed)
# 10000/10000 [==============================] - 97s 10ms/step - reward: 0.0192
# 13 episodes - episode_reward: 13.846 [5.000, 27.000] - loss: 0.015 - mean_absolute_error: 2.304 - mean_q: 2.778 - mean_eps: 0.312 - ale.lives: 2.043
#
# Interval 78 (770000 steps performed)
# 10000/10000 [==============================] - 95s 9ms/step - reward: 0.0212
# 12 episodes - episode_reward: 17.500 [4.000, 34.000] - loss: 0.014 - mean_absolute_error: 2.265 - mean_q: 2.732 - mean_eps: 0.303 - ale.lives: 2.173
#
# Interval 79 (780000 steps performed)
# 10000/10000 [==============================] - 96s 10ms/step - reward: 0.0196
# 12 episodes - episode_reward: 17.333 [6.000, 29.000] - loss: 0.014 - mean_absolute_error: 2.235 - mean_q: 2.696 - mean_eps: 0.294 - ale.lives: 2.141
#
# Interval 80 (790000 steps performed)
# 10000/10000 [==============================] - 96s 10ms/step - reward: 0.0187
# 14 episodes - episode_reward: 12.571 [5.000, 27.000] - loss: 0.014 - mean_absolute_error: 2.220 - mean_q: 2.678 - mean_eps: 0.285 - ale.lives: 2.110
#
# Interval 81 (800000 steps performed)
# 10000/10000 [==============================] - 96s 10ms/step - reward: 0.0198
# 11 episodes - episode_reward: 17.727 [7.000, 32.000] - loss: 0.014 - mean_absolute_error: 2.216 - mean_q: 2.673 - mean_eps: 0.276 - ale.lives: 1.946
#
# Interval 82 (810000 steps performed)
# 10000/10000 [==============================] - 95s 10ms/step - reward: 0.0187
# 12 episodes - episode_reward: 16.917 [5.000, 30.000] - loss: 0.014 - mean_absolute_error: 2.210 - mean_q: 2.665 - mean_eps: 0.267 - ale.lives: 2.196
#
# Interval 83 (820000 steps performed)
# 10000/10000 [==============================] - 96s 10ms/step - reward: 0.0167
# 13 episodes - episode_reward: 12.846 [6.000, 22.000] - loss: 0.014 - mean_absolute_error: 2.200 - mean_q: 2.653 - mean_eps: 0.258 - ale.lives: 2.143
#
# Interval 84 (830000 steps performed)
# 10000/10000 [==============================] - 97s 10ms/step - reward: 0.0185
# 12 episodes - episode_reward: 14.917 [2.000, 30.000] - loss: 0.014 - mean_absolute_error: 2.205 - mean_q: 2.658 - mean_eps: 0.249 - ale.lives: 1.977
#
# Interval 85 (840000 steps performed)
# 10000/10000 [==============================] - 96s 10ms/step - reward: 0.0214
# 12 episodes - episode_reward: 17.333 [9.000, 31.000] - loss: 0.014 - mean_absolute_error: 2.216 - mean_q: 2.671 - mean_eps: 0.240 - ale.lives: 1.966
#
# Interval 86 (850000 steps performed)
# 10000/10000 [==============================] - 96s 10ms/step - reward: 0.0221
# 14 episodes - episode_reward: 15.500 [4.000, 26.000] - loss: 0.014 - mean_absolute_error: 2.234 - mean_q: 2.693 - mean_eps: 0.231 - ale.lives: 2.080
#
# Interval 87 (860000 steps performed)
# 10000/10000 [==============================] - 97s 10ms/step - reward: 0.0204
# 11 episodes - episode_reward: 17.727 [6.000, 26.000] - loss: 0.014 - mean_absolute_error: 2.215 - mean_q: 2.669 - mean_eps: 0.222 - ale.lives: 2.034
#
# Interval 88 (870000 steps performed)
# 10000/10000 [==============================] - 98s 10ms/step - reward: 0.0179
# 13 episodes - episode_reward: 15.077 [8.000, 29.000] - loss: 0.014 - mean_absolute_error: 2.205 - mean_q: 2.658 - mean_eps: 0.213 - ale.lives: 1.989
#
# Interval 89 (880000 steps performed)
# 10000/10000 [==============================] - 96s 10ms/step - reward: 0.0189
# 12 episodes - episode_reward: 16.417 [9.000, 25.000] - loss: 0.014 - mean_absolute_error: 2.213 - mean_q: 2.668 - mean_eps: 0.204 - ale.lives: 1.979
#
# Interval 90 (890000 steps performed)
# 10000/10000 [==============================] - 96s 10ms/step - reward: 0.0201
# 11 episodes - episode_reward: 16.727 [6.000, 34.000] - loss: 0.014 - mean_absolute_error: 2.203 - mean_q: 2.656 - mean_eps: 0.195 - ale.lives: 2.065
#
# Interval 91 (900000 steps performed)
# 10000/10000 [==============================] - 98s 10ms/step - reward: 0.0198
# 12 episodes - episode_reward: 17.333 [10.000, 33.000] - loss: 0.014 - mean_absolute_error: 2.229 - mean_q: 2.687 - mean_eps: 0.186 - ale.lives: 2.053
#
# Interval 92 (910000 steps performed)
# 10000/10000 [==============================] - 100s 10ms/step - reward: 0.02020s - reward: 0
# 13 episodes - episode_reward: 15.462 [7.000, 30.000] - loss: 0.014 - mean_absolute_error: 2.221 - mean_q: 2.679 - mean_eps: 0.177 - ale.lives: 2.030
#
# Interval 93 (920000 steps performed)
# 10000/10000 [==============================] - 97s 10ms/step - reward: 0.0204
# 12 episodes - episode_reward: 16.083 [9.000, 29.000] - loss: 0.014 - mean_absolute_error: 2.217 - mean_q: 2.673 - mean_eps: 0.168 - ale.lives: 2.042
#
# Interval 94 (930000 steps performed)
# 10000/10000 [==============================] - 96s 10ms/step - reward: 0.0230
# 13 episodes - episode_reward: 18.231 [10.000, 30.000] - loss: 0.014 - mean_absolute_error: 2.207 - mean_q: 2.662 - mean_eps: 0.159 - ale.lives: 2.183
#
# Interval 95 (940000 steps performed)
# 10000/10000 [==============================] - 99s 10ms/step - reward: 0.0197 0s - reward: 0.01
# 12 episodes - episode_reward: 17.417 [5.000, 34.000] - loss: 0.013 - mean_absolute_error: 2.185 - mean_q: 2.636 - mean_eps: 0.150 - ale.lives: 2.046
#
# Interval 96 (950000 steps performed)
# 10000/10000 [==============================] - 98s 10ms/step - reward: 0.0192
# 11 episodes - episode_reward: 17.000 [8.000, 33.000] - loss: 0.014 - mean_absolute_error: 2.191 - mean_q: 2.642 - mean_eps: 0.141 - ale.lives: 2.205
#
# Interval 97 (960000 steps performed)
# 10000/10000 [==============================] - 99s 10ms/step - reward: 0.0193
# 13 episodes - episode_reward: 15.231 [4.000, 31.000] - loss: 0.014 - mean_absolute_error: 2.184 - mean_q: 2.633 - mean_eps: 0.132 - ale.lives: 2.209
#
# Interval 98 (970000 steps performed)
# 10000/10000 [==============================] - 100s 10ms/step - reward: 0.0191
# 10 episodes - episode_reward: 17.400 [5.000, 27.000] - loss: 0.014 - mean_absolute_error: 2.204 - mean_q: 2.657 - mean_eps: 0.123 - ale.lives: 2.110
#
# Interval 99 (980000 steps performed)
# 10000/10000 [==============================] - 99s 10ms/step - reward: 0.0165
# 15 episodes - episode_reward: 11.800 [4.000, 22.000] - loss: 0.014 - mean_absolute_error: 2.219 - mean_q: 2.675 - mean_eps: 0.114 - ale.lives: 2.012
#
# Interval 100 (990000 steps performed)
# 10000/10000 [==============================] - 98s 10ms/step - reward: 0.0161
# 13 episodes - episode_reward: 12.154 [4.000, 18.000] - loss: 0.014 - mean_absolute_error: 2.203 - mean_q: 2.656 - mean_eps: 0.105 - ale.lives: 2.046
#
# Interval 101 (1000000 steps performed)
# 10000/10000 [==============================] - 97s 10ms/step - reward: 0.0173
# 14 episodes - episode_reward: 12.857 [3.000, 27.000] - loss: 0.014 - mean_absolute_error: 2.209 - mean_q: 2.663 - mean_eps: 0.100 - ale.lives: 2.051
#
# Interval 102 (1010000 steps performed)
# 10000/10000 [==============================] - 98s 10ms/step - reward: 0.0153
# 15 episodes - episode_reward: 10.133 [5.000, 17.000] - loss: 0.014 - mean_absolute_error: 2.204 - mean_q: 2.656 - mean_eps: 0.100 - ale.lives: 2.139
#
# Interval 103 (1020000 steps performed)
# 10000/10000 [==============================] - 97s 10ms/step - reward: 0.0162
# 13 episodes - episode_reward: 12.538 [6.000, 24.000] - loss: 0.014 - mean_absolute_error: 2.208 - mean_q: 2.661 - mean_eps: 0.100 - ale.lives: 2.170
#
# Interval 104 (1030000 steps performed)
# 10000/10000 [==============================] - 97s 10ms/step - reward: 0.0195
# 12 episodes - episode_reward: 15.417 [5.000, 24.000] - loss: 0.014 - mean_absolute_error: 2.219 - mean_q: 2.673 - mean_eps: 0.100 - ale.lives: 2.207
#
# Interval 105 (1040000 steps performed)
# 10000/10000 [==============================] - 97s 10ms/step - reward: 0.0183
# 13 episodes - episode_reward: 13.462 [7.000, 28.000] - loss: 0.014 - mean_absolute_error: 2.225 - mean_q: 2.680 - mean_eps: 0.100 - ale.lives: 2.066
#
# Interval 106 (1050000 steps performed)
# 10000/10000 [==============================] - 97s 10ms/step - reward: 0.0162
# 14 episodes - episode_reward: 12.929 [6.000, 30.000] - loss: 0.014 - mean_absolute_error: 2.238 - mean_q: 2.696 - mean_eps: 0.100 - ale.lives: 2.100
#
# Interval 107 (1060000 steps performed)
# 10000/10000 [==============================] - 97s 10ms/step - reward: 0.0174
# 15 episodes - episode_reward: 11.000 [2.000, 18.000] - loss: 0.015 - mean_absolute_error: 2.259 - mean_q: 2.722 - mean_eps: 0.100 - ale.lives: 2.055
#
# Interval 108 (1070000 steps performed)
# 10000/10000 [==============================] - 97s 10ms/step - reward: 0.0177
# 14 episodes - episode_reward: 12.071 [5.000, 25.000] - loss: 0.014 - mean_absolute_error: 2.248 - mean_q: 2.708 - mean_eps: 0.100 - ale.lives: 2.082
#
# Interval 109 (1080000 steps performed)
# 10000/10000 [==============================] - 98s 10ms/step - reward: 0.0163
# 13 episodes - episode_reward: 13.308 [4.000, 24.000] - loss: 0.014 - mean_absolute_error: 2.247 - mean_q: 2.707 - mean_eps: 0.100 - ale.lives: 2.005
#
# Interval 110 (1090000 steps performed)
# 10000/10000 [==============================] - 98s 10ms/step - reward: 0.0186
# 11 episodes - episode_reward: 17.273 [6.000, 27.000] - loss: 0.014 - mean_absolute_error: 2.235 - mean_q: 2.694 - mean_eps: 0.100 - ale.lives: 2.027
#
# Interval 111 (1100000 steps performed)
# 10000/10000 [==============================] - 98s 10ms/step - reward: 0.0178
# 13 episodes - episode_reward: 13.923 [5.000, 22.000] - loss: 0.014 - mean_absolute_error: 2.237 - mean_q: 2.696 - mean_eps: 0.100 - ale.lives: 1.986
#
# Interval 112 (1110000 steps performed)
# 10000/10000 [==============================] - 98s 10ms/step - reward: 0.0176
# 14 episodes - episode_reward: 11.571 [4.000, 16.000] - loss: 0.014 - mean_absolute_error: 2.245 - mean_q: 2.706 - mean_eps: 0.100 - ale.lives: 1.999
#
# Interval 113 (1120000 steps performed)
# 10000/10000 [==============================] - 98s 10ms/step - reward: 0.0176
# 14 episodes - episode_reward: 12.214 [4.000, 22.000] - loss: 0.014 - mean_absolute_error: 2.227 - mean_q: 2.686 - mean_eps: 0.100 - ale.lives: 2.119
#
# Interval 114 (1130000 steps performed)
# 10000/10000 [==============================] - 98s 10ms/step - reward: 0.0187
# 12 episodes - episode_reward: 16.667 [6.000, 31.000] - loss: 0.014 - mean_absolute_error: 2.206 - mean_q: 2.661 - mean_eps: 0.100 - ale.lives: 2.111
#
# Interval 115 (1140000 steps performed)
# 10000/10000 [==============================] - 98s 10ms/step - reward: 0.0197
# 12 episodes - episode_reward: 15.750 [5.000, 24.000] - loss: 0.014 - mean_absolute_error: 2.204 - mean_q: 2.657 - mean_eps: 0.100 - ale.lives: 1.999
#
# Interval 116 (1150000 steps performed)
# 10000/10000 [==============================] - 99s 10ms/step - reward: 0.0197
# 12 episodes - episode_reward: 16.500 [7.000, 28.000] - loss: 0.014 - mean_absolute_error: 2.214 - mean_q: 2.670 - mean_eps: 0.100 - ale.lives: 2.074
#
# Interval 117 (1160000 steps performed)
# 10000/10000 [==============================] - 98s 10ms/step - reward: 0.0194
# 11 episodes - episode_reward: 17.273 [6.000, 25.000] - loss: 0.013 - mean_absolute_error: 2.227 - mean_q: 2.686 - mean_eps: 0.100 - ale.lives: 2.223
#
# Interval 118 (1170000 steps performed)
# 10000/10000 [==============================] - 97s 10ms/step - reward: 0.0184
# 13 episodes - episode_reward: 13.846 [3.000, 28.000] - loss: 0.014 - mean_absolute_error: 2.226 - mean_q: 2.683 - mean_eps: 0.100 - ale.lives: 2.045
#
# Interval 119 (1180000 steps performed)
# 10000/10000 [==============================] - 98s 10ms/step - reward: 0.0184
# 12 episodes - episode_reward: 15.750 [7.000, 22.000] - loss: 0.014 - mean_absolute_error: 2.207 - mean_q: 2.661 - mean_eps: 0.100 - ale.lives: 2.196
#
# Interval 120 (1190000 steps performed)
# 10000/10000 [==============================] - 98s 10ms/step - reward: 0.0197
# 13 episodes - episode_reward: 15.308 [6.000, 31.000] - loss: 0.014 - mean_absolute_error: 2.197 - mean_q: 2.650 - mean_eps: 0.100 - ale.lives: 2.152
#
# Interval 121 (1200000 steps performed)
# 10000/10000 [==============================] - 98s 10ms/step - reward: 0.0221
# 13 episodes - episode_reward: 16.846 [7.000, 28.000] - loss: 0.013 - mean_absolute_error: 2.201 - mean_q: 2.653 - mean_eps: 0.100 - ale.lives: 2.163
#
# Interval 122 (1210000 steps performed)
# 10000/10000 [==============================] - 97s 10ms/step - reward: 0.0187
# 12 episodes - episode_reward: 16.667 [5.000, 26.000] - loss: 0.014 - mean_absolute_error: 2.192 - mean_q: 2.643 - mean_eps: 0.100 - ale.lives: 2.098
#
# Interval 123 (1220000 steps performed)
# 10000/10000 [==============================] - 98s 10ms/step - reward: 0.0192
# 12 episodes - episode_reward: 16.000 [9.000, 26.000] - loss: 0.014 - mean_absolute_error: 2.194 - mean_q: 2.643 - mean_eps: 0.100 - ale.lives: 2.138
#
# Interval 124 (1230000 steps performed)
# 10000/10000 [==============================] - 97s 10ms/step - reward: 0.0184
# 13 episodes - episode_reward: 13.385 [4.000, 32.000] - loss: 0.014 - mean_absolute_error: 2.219 - mean_q: 2.675 - mean_eps: 0.100 - ale.lives: 2.134
#
# Interval 125 (1240000 steps performed)
# 10000/10000 [==============================] - 98s 10ms/step - reward: 0.0197
# 12 episodes - episode_reward: 17.333 [7.000, 30.000] - loss: 0.014 - mean_absolute_error: 2.209 - mean_q: 2.663 - mean_eps: 0.100 - ale.lives: 2.029
#
# Interval 126 (1250000 steps performed)
# 10000/10000 [==============================] - 97s 10ms/step - reward: 0.0199
# 11 episodes - episode_reward: 17.545 [7.000, 27.000] - loss: 0.014 - mean_absolute_error: 2.225 - mean_q: 2.682 - mean_eps: 0.100 - ale.lives: 1.998
#
# Interval 127 (1260000 steps performed)
# 10000/10000 [==============================] - 97s 10ms/step - reward: 0.0216
# 10 episodes - episode_reward: 19.000 [12.000, 31.000] - loss: 0.013 - mean_absolute_error: 2.221 - mean_q: 2.676 - mean_eps: 0.100 - ale.lives: 1.898
#
# Interval 128 (1270000 steps performed)
# 10000/10000 [==============================] - 97s 10ms/step - reward: 0.0206
# 12 episodes - episode_reward: 19.417 [5.000, 34.000] - loss: 0.014 - mean_absolute_error: 2.240 - mean_q: 2.699 - mean_eps: 0.100 - ale.lives: 2.169
#
# Interval 129 (1280000 steps performed)
# 10000/10000 [==============================] - 98s 10ms/step - reward: 0.0185
# 13 episodes - episode_reward: 14.462 [2.000, 23.000] - loss: 0.014 - mean_absolute_error: 2.213 - mean_q: 2.666 - mean_eps: 0.100 - ale.lives: 2.146
#
# Interval 130 (1290000 steps performed)
# 10000/10000 [==============================] - 98s 10ms/step - reward: 0.0197
# 12 episodes - episode_reward: 16.417 [6.000, 36.000] - loss: 0.014 - mean_absolute_error: 2.216 - mean_q: 2.671 - mean_eps: 0.100 - ale.lives: 2.107
#
# Interval 131 (1300000 steps performed)
# 10000/10000 [==============================] - 97s 10ms/step - reward: 0.0221
# 11 episodes - episode_reward: 20.182 [13.000, 28.000] - loss: 0.015 - mean_absolute_error: 2.211 - mean_q: 2.666 - mean_eps: 0.100 - ale.lives: 1.968
#
# Interval 132 (1310000 steps performed)
# 10000/10000 [==============================] - ETA: 0s - reward: 0.018 - 98s 10ms/step - reward: 0.0189
# 12 episodes - episode_reward: 15.417 [3.000, 24.000] - loss: 0.014 - mean_absolute_error: 2.246 - mean_q: 2.707 - mean_eps: 0.100 - ale.lives: 2.111
#
# Interval 133 (1320000 steps performed)
# 10000/10000 [==============================] - 100s 10ms/step - reward: 0.0207
# 12 episodes - episode_reward: 17.333 [6.000, 31.000] - loss: 0.015 - mean_absolute_error: 2.231 - mean_q: 2.690 - mean_eps: 0.100 - ale.lives: 2.161
#
# Interval 134 (1330000 steps performed)
# 10000/10000 [==============================] - 97s 10ms/step - reward: 0.0182
# 11 episodes - episode_reward: 15.091 [8.000, 23.000] - loss: 0.015 - mean_absolute_error: 2.230 - mean_q: 2.687 - mean_eps: 0.100 - ale.lives: 2.208
#
# Interval 135 (1340000 steps performed)
# 10000/10000 [==============================] - 97s 10ms/step - reward: 0.0207
# 13 episodes - episode_reward: 17.154 [6.000, 28.000] - loss: 0.015 - mean_absolute_error: 2.219 - mean_q: 2.675 - mean_eps: 0.100 - ale.lives: 2.162
#
# Interval 136 (1350000 steps performed)
# 10000/10000 [==============================] - 97s 10ms/step - reward: 0.0219
# 12 episodes - episode_reward: 18.500 [12.000, 31.000] - loss: 0.014 - mean_absolute_error: 2.215 - mean_q: 2.670 - mean_eps: 0.100 - ale.lives: 1.978
#
# Interval 137 (1360000 steps performed)
# 10000/10000 [==============================] - 97s 10ms/step - reward: 0.0175
# 10 episodes - episode_reward: 16.500 [7.000, 30.000] - loss: 0.014 - mean_absolute_error: 2.229 - mean_q: 2.687 - mean_eps: 0.100 - ale.lives: 2.172
#
# Interval 138 (1370000 steps performed)
# 10000/10000 [==============================] - 98s 10ms/step - reward: 0.0211
# 13 episodes - episode_reward: 16.538 [4.000, 31.000] - loss: 0.015 - mean_absolute_error: 2.240 - mean_q: 2.699 - mean_eps: 0.100 - ale.lives: 2.166
#
# Interval 139 (1380000 steps performed)
# 10000/10000 [==============================] - 99s 10ms/step - reward: 0.0217
# 12 episodes - episode_reward: 17.250 [8.000, 41.000] - loss: 0.014 - mean_absolute_error: 2.216 - mean_q: 2.671 - mean_eps: 0.100 - ale.lives: 2.069
#
# Interval 140 (1390000 steps performed)
# 10000/10000 [==============================] - 99s 10ms/step - reward: 0.0198
# 12 episodes - episode_reward: 17.417 [7.000, 27.000] - loss: 0.014 - mean_absolute_error: 2.191 - mean_q: 2.640 - mean_eps: 0.100 - ale.lives: 2.047
#
# Interval 141 (1400000 steps performed)
# 10000/10000 [==============================] - 98s 10ms/step - reward: 0.0185
# 12 episodes - episode_reward: 16.083 [8.000, 27.000] - loss: 0.015 - mean_absolute_error: 2.193 - mean_q: 2.641 - mean_eps: 0.100 - ale.lives: 2.117
#
# Interval 142 (1410000 steps performed)
# 10000/10000 [==============================] - 101s 10ms/step - reward: 0.0173
# 13 episodes - episode_reward: 13.154 [4.000, 27.000] - loss: 0.014 - mean_absolute_error: 2.199 - mean_q: 2.650 - mean_eps: 0.100 - ale.lives: 2.127
#
# Interval 143 (1420000 steps performed)
# 10000/10000 [==============================] - 104s 10ms/step - reward: 0.0201
# 12 episodes - episode_reward: 15.750 [7.000, 24.000] - loss: 0.014 - mean_absolute_error: 2.181 - mean_q: 2.628 - mean_eps: 0.100 - ale.lives: 2.170
#
# Interval 144 (1430000 steps performed)
# 10000/10000 [==============================] - 103s 10ms/step - reward: 0.0187
# 14 episodes - episode_reward: 13.714 [5.000, 24.000] - loss: 0.014 - mean_absolute_error: 2.168 - mean_q: 2.612 - mean_eps: 0.100 - ale.lives: 2.136
#
# Interval 145 (1440000 steps performed)
# 10000/10000 [==============================] - 103s 10ms/step - reward: 0.0215
# 13 episodes - episode_reward: 15.769 [6.000, 27.000] - loss: 0.014 - mean_absolute_error: 2.165 - mean_q: 2.609 - mean_eps: 0.100 - ale.lives: 2.137
#
# Interval 146 (1450000 steps performed)
# 10000/10000 [==============================] - 105s 10ms/step - reward: 0.02060s - reward: 0.
# 13 episodes - episode_reward: 17.308 [8.000, 25.000] - loss: 0.014 - mean_absolute_error: 2.158 - mean_q: 2.599 - mean_eps: 0.100 - ale.lives: 1.953
#
# Interval 147 (1460000 steps performed)
# 10000/10000 [==============================] - 103s 10ms/step - reward: 0.0205
# 9 episodes - episode_reward: 20.889 [14.000, 34.000] - loss: 0.014 - mean_absolute_error: 2.162 - mean_q: 2.604 - mean_eps: 0.100 - ale.lives: 2.304
#
# Interval 148 (1470000 steps performed)
# 10000/10000 [==============================] - 105s 10ms/step - reward: 0.0216
# 12 episodes - episode_reward: 17.667 [8.000, 33.000] - loss: 0.014 - mean_absolute_error: 2.139 - mean_q: 2.577 - mean_eps: 0.100 - ale.lives: 2.177
#
# Interval 149 (1480000 steps performed)
# 10000/10000 [==============================] - 107s 11ms/step - reward: 0.0195
# 11 episodes - episode_reward: 17.727 [6.000, 29.000] - loss: 0.014 - mean_absolute_error: 2.158 - mean_q: 2.601 - mean_eps: 0.100 - ale.lives: 2.080
#
# Interval 150 (1490000 steps performed)
# 10000/10000 [==============================] - 105s 11ms/step - reward: 0.0198
# 15 episodes - episode_reward: 14.067 [4.000, 25.000] - loss: 0.014 - mean_absolute_error: 2.169 - mean_q: 2.615 - mean_eps: 0.100 - ale.lives: 2.055
#
# Interval 151 (1500000 steps performed)
# 10000/10000 [==============================] - 102s 10ms/step - reward: 0.0200
# 13 episodes - episode_reward: 16.000 [5.000, 32.000] - loss: 0.015 - mean_absolute_error: 2.170 - mean_q: 2.617 - mean_eps: 0.100 - ale.lives: 1.980
#
# Interval 152 (1510000 steps performed)
# 10000/10000 [==============================] - 104s 10ms/step - reward: 0.0212
# 13 episodes - episode_reward: 15.538 [4.000, 24.000] - loss: 0.015 - mean_absolute_error: 2.186 - mean_q: 2.636 - mean_eps: 0.100 - ale.lives: 2.073
#
# Interval 153 (1520000 steps performed)
# 10000/10000 [==============================] - 107s 11ms/step - reward: 0.0210
# 11 episodes - episode_reward: 18.727 [8.000, 29.000] - loss: 0.015 - mean_absolute_error: 2.186 - mean_q: 2.634 - mean_eps: 0.100 - ale.lives: 2.070
#
# Interval 154 (1530000 steps performed)
# 10000/10000 [==============================] - 107s 11ms/step - reward: 0.0222
# 11 episodes - episode_reward: 20.727 [9.000, 34.000] - loss: 0.014 - mean_absolute_error: 2.208 - mean_q: 2.662 - mean_eps: 0.100 - ale.lives: 1.907
#
# Interval 155 (1540000 steps performed)
# 10000/10000 [==============================] - 105s 10ms/step - reward: 0.0230
# 10 episodes - episode_reward: 23.300 [13.000, 34.000] - loss: 0.015 - mean_absolute_error: 2.221 - mean_q: 2.677 - mean_eps: 0.100 - ale.lives: 2.003
#
# Interval 156 (1550000 steps performed)
# 10000/10000 [==============================] - 100s 10ms/step - reward: 0.0230
# 12 episodes - episode_reward: 19.500 [9.000, 33.000] - loss: 0.015 - mean_absolute_error: 2.204 - mean_q: 2.656 - mean_eps: 0.100 - ale.lives: 2.017
#
# Interval 157 (1560000 steps performed)
# 10000/10000 [==============================] - 98s 10ms/step - reward: 0.0222
# 11 episodes - episode_reward: 19.364 [10.000, 36.000] - loss: 0.015 - mean_absolute_error: 2.204 - mean_q: 2.657 - mean_eps: 0.100 - ale.lives: 1.998
#
# Interval 158 (1570000 steps performed)
# 10000/10000 [==============================] - 98s 10ms/step - reward: 0.0203
# 14 episodes - episode_reward: 15.143 [7.000, 25.000] - loss: 0.015 - mean_absolute_error: 2.216 - mean_q: 2.672 - mean_eps: 0.100 - ale.lives: 1.988
#
# Interval 159 (1580000 steps performed)
# 10000/10000 [==============================] - 100s 10ms/step - reward: 0.0195
# 15 episodes - episode_reward: 12.800 [2.000, 29.000] - loss: 0.015 - mean_absolute_error: 2.222 - mean_q: 2.680 - mean_eps: 0.100 - ale.lives: 2.057
#
# Interval 160 (1590000 steps performed)
# 10000/10000 [==============================] - 100s 10ms/step - reward: 0.0218
# 13 episodes - episode_reward: 16.308 [6.000, 30.000] - loss: 0.015 - mean_absolute_error: 2.223 - mean_q: 2.681 - mean_eps: 0.100 - ale.lives: 2.073
#
# Interval 161 (1600000 steps performed)
# 10000/10000 [==============================] - 101s 10ms/step - reward: 0.0208
# 14 episodes - episode_reward: 15.429 [8.000, 26.000] - loss: 0.015 - mean_absolute_error: 2.224 - mean_q: 2.682 - mean_eps: 0.100 - ale.lives: 2.224
#
# Interval 162 (1610000 steps performed)
# 10000/10000 [==============================] - 100s 10ms/step - reward: 0.0217
# 11 episodes - episode_reward: 19.545 [6.000, 27.000] - loss: 0.015 - mean_absolute_error: 2.209 - mean_q: 2.664 - mean_eps: 0.100 - ale.lives: 2.073
#
# Interval 163 (1620000 steps performed)
# 10000/10000 [==============================] - 99s 10ms/step - reward: 0.0210
# 12 episodes - episode_reward: 16.167 [7.000, 32.000] - loss: 0.015 - mean_absolute_error: 2.224 - mean_q: 2.680 - mean_eps: 0.100 - ale.lives: 2.229
#
# Interval 164 (1630000 steps performed)
# 10000/10000 [==============================] - 98s 10ms/step - reward: 0.0212
# 14 episodes - episode_reward: 16.071 [5.000, 35.000] - loss: 0.015 - mean_absolute_error: 2.208 - mean_q: 2.662 - mean_eps: 0.100 - ale.lives: 2.198
#
# Interval 165 (1640000 steps performed)
# 10000/10000 [==============================] - 99s 10ms/step - reward: 0.0199
# 11 episodes - episode_reward: 18.727 [6.000, 34.000] - loss: 0.015 - mean_absolute_error: 2.183 - mean_q: 2.632 - mean_eps: 0.100 - ale.lives: 2.005
#
# Interval 166 (1650000 steps performed)
# 10000/10000 [==============================] - 99s 10ms/step - reward: 0.0198
# 11 episodes - episode_reward: 17.818 [9.000, 29.000] - loss: 0.015 - mean_absolute_error: 2.205 - mean_q: 2.659 - mean_eps: 0.100 - ale.lives: 2.100
#
# Interval 167 (1660000 steps performed)
# 10000/10000 [==============================] - 99s 10ms/step - reward: 0.0221
# 12 episodes - episode_reward: 17.083 [12.000, 24.000] - loss: 0.015 - mean_absolute_error: 2.208 - mean_q: 2.664 - mean_eps: 0.100 - ale.lives: 1.929
#
# Interval 168 (1670000 steps performed)
# 10000/10000 [==============================] - 99s 10ms/step - reward: 0.0180
# 12 episodes - episode_reward: 15.667 [8.000, 21.000] - loss: 0.016 - mean_absolute_error: 2.233 - mean_q: 2.693 - mean_eps: 0.100 - ale.lives: 2.053
#
# Interval 169 (1680000 steps performed)
# 10000/10000 [==============================] - 98s 10ms/step - reward: 0.0206
# 12 episodes - episode_reward: 17.167 [5.000, 31.000] - loss: 0.015 - mean_absolute_error: 2.254 - mean_q: 2.719 - mean_eps: 0.100 - ale.lives: 1.967
#
# Interval 170 (1690000 steps performed)
# 10000/10000 [==============================] - 98s 10ms/step - reward: 0.0174
# 11 episodes - episode_reward: 15.636 [9.000, 21.000] - loss: 0.015 - mean_absolute_error: 2.263 - mean_q: 2.730 - mean_eps: 0.100 - ale.lives: 2.062
#
# Interval 171 (1700000 steps performed)
# 10000/10000 [==============================] - 98s 10ms/step - reward: 0.0199
# 12 episodes - episode_reward: 16.000 [2.000, 27.000] - loss: 0.015 - mean_absolute_error: 2.279 - mean_q: 2.747 - mean_eps: 0.100 - ale.lives: 2.014
#
# Interval 172 (1710000 steps performed)
# 10000/10000 [==============================] - 98s 10ms/step - reward: 0.0199
# 13 episodes - episode_reward: 15.462 [6.000, 23.000] - loss: 0.015 - mean_absolute_error: 2.300 - mean_q: 2.774 - mean_eps: 0.100 - ale.lives: 2.123
#
# Interval 173 (1720000 steps performed)
# 10000/10000 [==============================] - 98s 10ms/step - reward: 0.0202
# 14 episodes - episode_reward: 15.643 [5.000, 27.000] - loss: 0.015 - mean_absolute_error: 2.306 - mean_q: 2.780 - mean_eps: 0.100 - ale.lives: 2.051
#
# Interval 174 (1730000 steps performed)
# 10000/10000 [==============================] - 97s 10ms/step - reward: 0.0217
# 11 episodes - episode_reward: 17.273 [8.000, 26.000] - loss: 0.016 - mean_absolute_error: 2.329 - mean_q: 2.809 - mean_eps: 0.100 - ale.lives: 2.170
#
# Interval 175 (1740000 steps performed)
# 10000/10000 [==============================] - 97s 10ms/step - reward: 0.0224
# done, took 16606.421 seconds
# Testing for 10 episodes ...
# Episode 1: reward: 13.000, steps: 670
# Episode 2: reward: 12.000, steps: 621
# Episode 3: reward: 15.000, steps: 793
# Episode 4: reward: 16.000, steps: 784
# Episode 5: reward: 22.000, steps: 911
# Episode 6: reward: 20.000, steps: 746
# Episode 7: reward: 27.000, steps: 834
# Episode 8: reward: 13.000, steps: 625
# Episode 9: reward: 21.000, steps: 1111
# Episode 10: reward: 30.000, steps: 1200
# Testing for 10 episodes ...
# Episode 1: reward: 24.000, steps: 961
# Episode 2: reward: 26.000, steps: 1024
# Episode 3: reward: 14.000, steps: 821
# Episode 4: reward: 7.000, steps: 354
# Episode 5: reward: 21.000, steps: 915
# Episode 6: reward: 25.000, steps: 991
# Episode 7: reward: 19.000, steps: 860
# Episode 8: reward: 11.000, steps: 680
# Episode 9: reward: 9.000, steps: 613
# Episode 10: reward: 19.000, steps: 951

# %%
img.ndim
# Out:
# 3

# %%
env
# Out:
# <TimeLimit<AtariEnv<SpaceInvaders-v0>>>

# %%
weights_filename = 'dqn_{}_weights.h5f'.format(args.env_name)
if args.weights:
    weights_filename = args.weights
dqn.load_weights(weights_filename)
dqn.test(env, nb_episodes=10, visualize=True)
# Out:
# Testing for 10 episodes ...
# Episode 1: reward: 27.000, steps: 980
# Episode 2: reward: 26.000, steps: 1016
# Episode 3: reward: 22.000, steps: 912
# Episode 4: reward: 16.000, steps: 807
# Episode 5: reward: 17.000, steps: 717
# Episode 6: reward: 12.000, steps: 645
# Episode 7: reward: 24.000, steps: 857
# Episode 8: reward: 18.000, steps: 829
# Episode 9: reward: 17.000, steps: 839
# Episode 10: reward: 20.000, steps: 816
