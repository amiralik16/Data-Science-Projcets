# %%
import numpy as np
import pandas as pd
from pylab import plot,show
from numpy import *
from alpha_vantage.timeseries import TimeSeries
from alpha_vantage.techindicators import TechIndicators

# %%
ts = TimeSeries(key='ARTSA8ZXDXMI2GB4', output_format='pandas',indexing_type='integer')

# %%
temp = ts.get_daily('GOOG',outputsize='full')

# %%
closes = temp[0]['4. close'][:]
plot(closes); show()

# %%
lag1 = 2
lags = range(lag1, 20)
tau = [sqrt(std(subtract(closes[lag:], closes[:-lag]))) for lag in lags]
plot(log(lags), log(tau)); show()
m = polyfit(log(lags), log(tau), 1)
hurst = m[0]*2
print(f"hurst = {hurst}")
# Out:
# hurst = 0.3981603024016154
